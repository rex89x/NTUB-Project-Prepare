# %%
# !pip install psycopg2

# %%
#連結PGSQL
import psycopg2

conn = psycopg2.connect(database = "d7eu9qsublnd6e",
             user = "lvbstcegsalqac", 
             password = "a1001590e6979b1c0dcc8ac371462f756c1b8c5f8db7cb7d3c1df952323bf011", 
             host = "184.73.198.174", 
             port = "5432"
             )

print("Opened database successfully")

cur = conn.cursor()

cur.execute("SELECT news_id, news_datetime, news_title, news_content, news_website, news_link from news")
rows = cur.fetchall()
for row in rows:
   print ("ID = ", row[0])
   print ("時間 = ", row[1])
   print ("標題 = ", row[2])
   print ("內容 = ", row[3])
   print ("網站 = ", row[4])
   print ("連結 = ", row[5])

print ("Operation done successfully")
conn.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Opened database successfully
# ID =  1000000002
# 時間 =  2021-04-26T19:39:40.330Z
# 標題 =  Italian police arrest suspected Nigerian gang
# 內容 =  Police say the gang used bitcoins to carry out illegal financial transactions on the dark web.
# 網站 =  bbc
# 連結 =  https://www.bbc.com/news/world-europe-56895864
# ID =  1000000003
# 時間 =  2021-04-23T16:54:54.326Z
# 標題 =  Turkey launches international hunt for crypto boss
# 內容 =  Faruk Fatih Ozer is believed to have fled to Albania with an alleged $2bn from 391,000 investors.
# 網站 =  bbc
# 連結 =  https://www.bbc.com/news/world-europe-56865119
# ID =  1000000004
# 時間 =  2021-04-22T13:13:59.019Z
# ...

# %%
"""
Database PGSQL 'default': { 'ENGINE': 'django.db.backends.postgresql',
                #PostgreSQL 'NAME': 'd7eu9qsublnd6e',
                #資料庫名稱 'USER': 'lvbstcegsalqac', 
                #資料庫帳號 'PASSWORD': 'a1001590e6979b1c0dcc8ac371462f756c1b8c5f8db7cb7d3c1df952323bf011', 
                #資料庫密碼 'HOST': '184.73.198.174', 
                #Server(伺服器)位址 'PORT': '5432' #PostgreSQL Port號 
               }
"""

# %%
"""
# 方法一: 使用pymsql.connect方法
import pymysql

# Connect to the database
eng = pymysql.connect(
    host='localhost',   # host:資料庫地址/本機使用localhost
    user='user',      # user:使用者名稱
    password='passwd',   # password:密碼
    db='db',        # db:資料庫名             
    charset='utf8'     # charset:資料庫編碼 # charset='utf8'是解決中文亂碼
    )
"""
# Out:
# "\n# 方法一: 使用pymsql.connect方法\nimport pymysql\n\n# Connect to the database\neng = pymysql.connect(\n    host='localhost',   # host:資料庫地址/本機使用localhost\n    user='user',      # user:使用者名稱\n    password='passwd',   # password:密碼\n    db='db',        # db:資料庫名             \n    charset='utf8'     # charset:資料庫編碼 # charset='utf8'是解決中文亂碼\n    )\n"

# %%
"""
# 方法二: 使用create_engine方法
from sqlarchemy import create_engine

create_engine("mysql+pymysql://<username>:<password>@<host>/<dbname>[?<options>]")

# mysql:資料庫型別
# pymysql:驅動器型別
# uername:使用者名稱
# password:密碼
# host:資料庫地址/本機使用localhost
# dbname:資料庫名
# options:資料庫編碼格式如:charset=utf8
# 連線sample
"""
