# %%
#參考網站連結
#https://iter01.com/418571.html

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager
from itertools import accumulate

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#設定matplotlib繪圖時的字型
my_font = font_manager.FontProperties(fname = "drive/MyDrive/二技資管一甲/下學期/news_dataset/songti.ttc")

# %%
#統計句子長度及長度出現的頻數
df = pd.read_csv("drive/MyDrive/二技資管一甲/下學期/news_dataset/corpus.csv")
print(df.groupby('label')['label'].count())

df['length'] = df['evaluation'].apply(lambda x: len(x))
len_df = df.groupby('length').count()
sent_length = len_df.index.tolist()
sent_freq = len_df['evaluation'].tolist()
# Out:
# label
# 正面    1908
# 負面    2375
# Name: label, dtype: int64

# %%
# 繪製句子長度及出現頻數統計圖
plt.bar(sent_length, sent_freq)
plt.title("句子長度及出現頻數統計圖", fontproperties = my_font)
plt.xlabel("句子長度", fontproperties = my_font)
plt.ylabel("句子長度出現的頻數", fontproperties = my_font)
plt.savefig("/句子長度及出現頻數統計圖.png")
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38263 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 29694 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38971 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 32113 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 35336 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22294 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38263 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 29694 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38971 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25976 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 32113 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 35336 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22294 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#繪製句子長度累積分佈函式(CDF)
sent_pentage_list = [(count/sum(sent_freq)) for count in accumulate(sent_freq)]

# %%
#繪製CDF
plt.plot(sent_length, sent_pentage_list)

# %%
#尋找分位點為quantile的句子長度
quantile = 0.91
#print(list(sent_pentage_list))
for length, per in zip(sent_length, sent_pentage_list):
    if round(per, 2) == quantile:
        index = length
        break
print("\n分位點為%s的句子長度:%d." % (quantile, index))
# Out:
# 分位點為0.91的句子長度:183.

# %%
# 繪製句子長度累積分佈函式圖
plt.plot(sent_length, sent_pentage_list)
plt.hlines(quantile, 0, index, colors = "c", linestyles = "dashed")
plt.vlines(index, 0, quantile, colors = "c", linestyles = "dashed")
plt.text(0, quantile, str(quantile))
plt.text(index, 0, str(index))
plt.title("句子長度累積分佈函式圖", fontproperties = my_font)
plt.xlabel("句子長度", fontproperties = my_font)
plt.ylabel("句子長度累積頻率", fontproperties = my_font)
plt.savefig("./句子長度累積分佈函式圖.png")
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38263 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 31309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20296 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22294 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38263 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 38971 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 31309 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 38971 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20296 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22294 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#模型總程式碼
# -*- coding: utf-8 -*-

import pickle
import numpy as np
import pandas as pd
from keras.utils import np_utils, plot_model
from keras.models import Sequential
from keras.preprocessing.sequence import pad_sequences
from keras.layers import LSTM, Dense, Embedding, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 匯入資料
# 檔案的資料中，特徵為evaluation, 類別為label.
def load_data(filepath, input_shape = 20):
    df = pd.read_csv("drive/MyDrive/二技資管一甲/下學期/news_dataset/corpus.csv")

    # 標籤及詞彙表
    labels, vocabulary = list(df['label'].unique()), list(df['evaluation'].unique())

    # 構造字元級別的特徵
    string = ''
    for word in vocabulary:
        string += word

    vocabulary = set(string)

    # 字典列表
    word_dictionary = {word: i + 1 for i, word in enumerate(vocabulary)}
    with open('word_dict.pk', 'wb') as f:
        pickle.dump(word_dictionary, f)
    inverse_word_dictionary = {i + 1: word for i, word in enumerate(vocabulary)}
    label_dictionary = {label: i for i, label in enumerate(labels)}
    with open('label_dict.pk', 'wb') as f:
        pickle.dump(label_dictionary, f)
    output_dictionary = {i: labels for i, labels in enumerate(labels)}

    vocab_size = len(word_dictionary.keys()) # 詞彙表大小
    label_size = len(label_dictionary.keys()) # 標籤類別數量

    # 序列填充，按input_shape填充，長度不足的按0補充
    x = [[word_dictionary[word] for word in sent] for sent in df['evaluation']]
    x = pad_sequences(maxlen = input_shape, sequences = x, padding = 'post', value = 0)
    y = [[label_dictionary[sent]] for sent in df['label']]
    y = [np_utils.to_categorical(label, num_classes = label_size) for label in y]
    y = np.array([list(_[0]) for _ in y])

    return x, y, output_dictionary, vocab_size, label_size, inverse_word_dictionary

# 建立深度學習模型， Embedding + LSTM + Softmax.
def create_LSTM(n_units, input_shape, output_dim, filepath):
    x, y, output_dictionary, vocab_size, label_size, inverse_word_dictionary = load_data(filepath)
    model = Sequential()
    model.add(Embedding(input_dim = vocab_size + 1, output_dim = output_dim,
                        input_length = input_shape, mask_zero=True))
    model.add(LSTM(n_units, input_shape = (x.shape[0], x.shape[1])))
    model.add(Dropout(0.2))
    model.add(Dense(label_size, activation = 'softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

    plot_model(model, to_file = './model_lstm.png', show_shapes = True)
    model.summary()

    return model

# 模型訓練
def model_train(input_shape, filepath, model_save_path):

    # 將資料集分為訓練集和測試集，佔比為9:1
    # input_shape = 100
    x, y, output_dictionary, vocab_size, label_size, inverse_word_dictionary = load_data(filepath, input_shape)
    train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.1, random_state = 42)

    # 模型輸入引數，需要自己根據需要調整
    n_units = 100
    batch_size = 32
    epochs = 5
    output_dim = 20

    # 模型訓練
    lstm_model = create_LSTM(n_units, input_shape, output_dim, filepath)
    lstm_model.fit(train_x, train_y, epochs = epochs, batch_size = batch_size, verbose = 1)

    # 模型儲存
    lstm_model.save(model_save_path)

    N = test_x.shape[0]  # 測試的條數
    predict = []
    label = []
    for start, end in zip(range(0, N, 1), range(1, N + 1, 1)):
        sentence = [inverse_word_dictionary[i] for i in test_x[start] if i != 0]
        y_predict = lstm_model.predict(test_x[start:end])
        label_predict = output_dictionary[np.argmax(y_predict[0])]
        label_true = output_dictionary[np.argmax(test_y[start:end])]
        print(''.join(sentence), label_true, label_predict) # 輸出預測結果
        predict.append(label_predict)
        label.append(label_true)

    acc = accuracy_score(predict, label) # 預測準確率
    print('模型在測試集上的準確率為: %s.' % acc)

if __name__ == '__main__':
    filepath = './corpus.csv'
    input_shape = 180
    model_save_path = './corpus_model.h5'
    model_train(input_shape, filepath, model_save_path)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 180, 20)           43380
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               48400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 202
# =================================================================
# Total params: 91,982
# Trainable params: 91,982
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 121/121 [==============================] - 25s 173ms/step - loss: 0.5989 - accuracy: 0.6932
# Epoch 2/5
# 121/121 [==============================] - 21s 171ms/step - loss: 0.2363 - accuracy: 0.9207
# Epoch 3/5
# 121/121 [==============================] - 21s 171ms/step - loss: 0.1710 - accuracy: 0.9455
# Epoch 4/5
# 121/121 [==============================] - 21s 171ms/step - loss: 0.1466 - accuracy: 0.9514
# Epoch 5/5
# 121/121 [==============================] - 21s 172ms/step - loss: 0.1312 - accuracy: 0.9590
# 硬體一般，但是軟體很棒， 負面 負面
# 客服態度好。電視還沒有開始用，還不知道效果。用了再評價 正面 正面
# 對的起這樣的價錢 支援京東 想要下單的親可以放心下單 加油 語音遙控器沒有 希望京東送一個 謝謝 負面 負面
# 非常差，8月8日1元預購的電視禮包，說不發就不發了，真是非常差勁，真後悔在這家店買東西，大家不要再來了。 負面 負面
# 京東物流慢了些，本來應該昨天送到的，結果今天才送到。電視還可以，稍微有點延遲，價效比很高。 負面 負面
# 後還選擇了這個創維一些國產的品牌，但是仔細參考引數之後還是做出了一個大膽的選擇，選擇的微鯨，使用了，之後的感覺非常的不錯，老婆也非常的喜歡，感覺比那個樂視的話還是有一定的優勢。可惜的話就是會員不夠多，然後的話價格稍微貴了一點，現在可能那個平板液晶平板這一塊也漲價了，所以說這個也情有可原。喜歡的可以大膽下手了，不會失望的，至少比創維，海信要好多了…價效比更高！ 負面 負面
# 臥室用的，畫面挺清晰，但是不能離近看，否則顏色會很詭異，安裝師傅挺好的 正面 正面
# 挺薄的外觀挺漂亮，色彩還行，就是有拖影清晰度不夠好，這點挺不滿意，。問客服問題反應太慢了半天才回答。 負面 負面
# 不錯，挺好的，真不錯很喜歡 正面 正面
# 到貨非常快，執行速度快，介面清晰，非常好。 正面 正面
# 總的來說對這款機器不滿意，漏光嚴重，廠家說不屬於質量問題。 負面 負面
# 開機稍微有些慢，其他都蠻好的。當天送回，棒 負面 負面
# 太差。送支架活動簡直是給客戶添堵的，收到電視沒有贈送的支架，無法安裝。聯絡客服說收貨後7日發，第3天跟進，說沒有登記需要登記確認後7日後再發。本來很簡單的事情，商家可以申請售後安裝免除支架費給客戶提供方便，現在弄得電視放家裡10天都沒法安裝。看網上都是因為支架給差評的。一個產品沒有好的服務，必然不會長久，也許不久商業教科書會有一個支架毀了一個品牌的經典案例。 負面 負面
# 特別喜歡，很大，很清晰，特別實惠，活動的時候買的。 正面 正面
# 電視整體還是滿意，說說不滿意的地方，1電視開機系統準備太頻繁，時間兩分鐘左右，感覺很窩心，2習慣了使用機頂盒遙控器，此電視遙控器不能被學習，如果看機頂盒直播節目就得用兩個遙控器，很不方便。其他因為才使用還沒發現。 負面 負面
# 適用了幾天，畫質不錯，看高清沒有拖影現象，機身金色的邊框看著也很大氣。電視買給父母看。只是有一點不太滿意。6月1日秒殺時候都不能能用滿2000減100的券，後來的秒殺都能用券了，等於買貴了100。鬱悶。 負面 負面
# 安裝師傅很負責，說是空心牆，多加了幾顆螺絲固定。電視試看了下感覺不錯。 晒單： 收起 向左轉 向右轉 正面 正面
# 買電器到京東還是可信的！發貨速度快，第二天貨已經收到了。電視機的清晰度很好 正面 正面
# 過來了。送貨師傅也很耐心的幫我驗貨，看看外觀有沒有損傷，電視能不能正常開機，試完後還幫我把包裝盒重新裝上，像剛送來的一樣。非常好。 最後，安裝師傅也很好，由於預約的時間到了下午，可能他來不及來幫我安裝，但是他竟然在過了下班時間加班來幫我把電視裝好，裝好之後也幫我把盒子這些都除錯好了，真是非常贊。 總之，這次的電視買得很贊，服務也很好。感謝送貨師傅和安裝師傅！ 正面 正面
# 雙11，2549入手，兩千多的電視做到這份上，真的蠻不錯了啊。 正面 正面
# 不錯。。。。。 正面 正面
# 除了開機慢點以外，其他都還能接受，基本算是物美價廉吧，京東自營的電器可以放心。唯一的遺憾是網路不行，無法刷卡支付。京東幫工作人員很給力，好評。 負面 負面
# 這個總開關在電視機的右下角，不能用遙控器關，這點不是很好。語音點播功能試了下還不錯，挺精準。看戶外節目是感覺畫質不是很清晰，顏色有點豔，其他暫時還沒發現什麼，價格很便宜，希望質量能有保證 負面 負面
# 電視不錯，外觀也漂亮，好評好評。 正面 正面
# 買了兩款電視，55寸的表現出眾，效能強勁，價效比很有誘惑力。這款32寸的就稍顯不足，款式陳舊，效能一般，價錢沒優勢，略感遺憾。 負面 負面
# 很好很好，很實惠 正面 正面
# 老顧客了，非常滿意！ 正面 正面
# 確實是沒有辜負期望，值得購買，信賴大！ 正面 正面
# 電視剛開始開機有點慢，後來更新系統以後就沒這個問題了。總體來說不錯，之前買過一臺TCL，感覺和老牌的機器一樣好 負面 負面
# 對微鯨有些失望，畫質沒有想象的好，會員也看不了啥 負面 負面
# 後還選擇了這個創維一些國產的品牌，但是仔細參考引數之後還是做出了一個大膽的選擇，選擇的微鯨，使用了，之後的感覺非常的不錯，老婆也非常的喜歡，感覺比那個樂視的話還是有一定的優勢。可惜的話就是會員不夠多，然後的話價格稍微貴了一點，現在可能那個平板液晶平板這一塊也漲價了，所以說這個也情有可原。喜歡的可以大膽下手了，不會失望的，至少比創維，海信要好多了…價效比更高！ 負面 負面
# 電視機算不錯，開機待頻好慢，領取會員操作好麻煩，幾天了至今沒領。 負面 負面
# 其他都可以，就是wifi連線上了不能看視訊 負面 負面
# 開箱通電後沒啥問題，送貨的師傅還是很負責的。曲面屏的確上檔次。自己上幾顆螺絲安裝了，希望不要出問題。 正面 負面
# 物流及服務都特別棒，更棒的是售後服務，給你們點贊 正面 正面
# 不錯，就是系統不太好，不適合老人操作 負面 負面
# 這個hdr我也找不到，不會用還沒有研究透，等有空再研究。送貨很及時，上午收到貨下午安裝師傅到了，安裝師傅裝的很用心，服務態度很好 負面 正面
# 發貨快，送貨上門，當場拆箱驗螢幕；小米剛出了32寸1099元，最近降100元，但是要預約，所以買了這款；比小米32寸款好的就是記憶體8G喇叭聲更響送一年會員；缺點如下：電視機太厚不夠薄，系統不好用不夠人性化爸媽嫌麻煩，安裝的直播軟體設定開機重啟，不能自啟！ 負面 負面
# 物流真快頭天下單第二天就到了比某 保強多了 正面 正面
# 覺得一般，畫面清晰度不高。其他還是 負面 負面
# 顯示效果一般，色彩過度不平滑，語音功能比較雞助，不過價格合適，價效比比較高。 負面 負面
# 非常漂亮的電視機，比商場便宜多了，可以的 正面 正面
# 第二臺微鯨電視，價效比高，輕微漏光，比去年貴了不少 負面 負面
# 很清晰，蠻好的，價格一貴 負面 負面
# 發貨前一天電話聯絡確定送貨時間地址，送貨師傅同時負責開箱驗貨並安裝。這種品牌質量這種服務態度太贊啦??? 正面 負面
# 昨天到貨，我不在家，特意請表弟試了數字電視，又試了網路，他說反應挺快的，內容豐富，價效比高，雙12入手，真的很實惠！ 希望快點放假，守著電視，把好劇連連看！ 正面 正面
# 1.機子看了5天了，挺好的，符合描述的硬屏，大屏，較薄，14kg。 2.畫面清晰，贈送一年的會員，可以看騰訊VIP，但是隻有超清影片才能體現4k的畫質。 3.可以通過小鷹直播看電視直播，系統自帶，但是某些電視臺的畫質非常不好。 4.遙控器簡潔好用，如圖。但是贈送手環是營銷手段，諮詢客服說只有300名。早說.... 總體超值超值超值 負面 負面
# 速度太快了..昨天晚上下單下午就送過來了..快遞小哥太給力了..正品 正面 正面
# 我的型號是創維65寸H7超薄的 昨天剛開機 電視給我感覺就是小了一點 我本來打算放客廳 現在放 臥室了 我房間要買創維100寸的藍芽遙控器 隨意切換一點都不卡，點什麼都是秒出來 好看 大氣我還要 再買一臺100寸的.真的好喜歡他的架子 就是好看 不卡 大氣 買的你放心 買的你安心 買的你絕對不後悔走過路過 千萬別錯過 支援買 買買 差不多了 我去忙了 非常好 正面 負面
# 電視效果還不錯，價效比可以接受，剛開始播放高清片源時，有一點卡。電視放在桌子上，稍微有點單薄，有孩子還得掛起來比較安全。快遞稍微有點慢，不過事出有因，總體說的過去吧。 負面 負面
# 非常超值的平板電視，大小剛合適，4K高清確實效果好，操作方便，片源豐富，百事通很爽，再買兩個小的放臥室，絕對的高價效比之王，買對了。 正面 正面
# 就不上圖了 一句話還不錯 正面 負面
# 電視不錯，很喜歡 正面 正面
# 感覺買小了點，還是能看，正品 正面 正面
# ，但是僅僅出現了一次，後來經過諮詢客服，重新連就好了，語音識別率很高，贊一個。總的說來，這款電視有幾個優勢：首先是創維品牌，售後有保障，大品牌值得信賴；其次就是價效比，在這個價位能買這個配置和尺寸的，估計也只能買其他一些非主流牌子；第三，顏值和配置都比較高；第四，京東的服務不錯，物流也快。綜合以上幾點，客觀的說，這款電視非常值得入手，想入手的小夥伴抓緊入手! 正面 正面
# 外觀大氣，系統流暢。內建工具豐富，購物非常滿意！ 正面 正面
# 利用藍芽智慧遙控器語音操作，識別率高，快捷實用，值得稱讚。微鯨Live裡面有不少4K資源，只是沒註冊會員暫不能觀看，以後再追評吧。客服態度不錯，有問必答。不足之處因為是國產硬屏，色彩的豔麗度不如進口屏；另外USB等外用介面數量偏少了些，使用上稍顯不便。考慮到購買消費群的年齡段，在促銷活動時，如果能贈送配套的遊戲手柄，那麼競爭力無疑會更強。總體好評，值得推薦! 負面 負面
# 點17分打售後電話預約安裝。售後一直沒有和我們聯絡！老公早上又自己打電話去主動聯絡，售後說他們系統沒有登記，讓我們等著他們再安排，我就和京東售前聯絡，售前也不管，只會像復讀機一樣讓我自己找售後.。真是夠了，實在忍不了給了差評。要買的親慎重，東西我確實還沒有用不知道效果，但是服務確實不敢恭維，受得氣的再考慮購買哈！本來一星也不想給，但是選擇不了零星！氣的我胃疼 負面 負面
# 價格實惠功能強悍。 正面 正面
# 開關機沒有廣告，是選擇微鯨的原因。電視的外觀和畫質還不錯，喇叭效果和遙控語音效果不太理想，但對於不到3000的價位，還算不錯? 負面 負面
# 55英寸大屏，清晰。送貨小哥辛苦了。唯一不足是支架不算太穩，有點搖晃。片源不少，系統反應也快，下次還會選擇微鯨。 負面 負面
# 電視挺好的，暫時沒什麼問題，反應有點慢，記憶體加1g就完美了 負面 負面
# 對比了很多家產品. 最終選擇了新興品牌微鯨. 電視4天送到 相比起來較慢. 送貨態度很不好. 好像誰欠他錢似的. 電視外包裝箱被雨淋溼了. 都壞了. 電視整體還湊合吧. 沒有很驚豔. 如果需要放在電視櫃上 櫃長要140cm以上. 能玩的遊戲有限.而且都是小遊戲. 總體不太值 負面 負面
# 物流很快，就是安裝費有點貴，要是免費安裝就更好了，總的來說還不錯 正面 負面
# 差評 服務態度差 搞活動還有內幕 負面 負面
# 老公幫叔叔買的~小米的品牌一直喜歡 這次價格還可以 正面 正面
# 很好，很不錯 正面 正面
# 還不錯感覺、哈哈哈。用幾個月看看 好在追評 正面 正面
# 不錯 正面 正面
# 買個了5000塊的的電視，結果因為客服問題。電視到了幾天放等個掛架。你掛架和電視分開送就算了，明明是下單就可以登記發貨掛架的。結果跟我說收到貨才登記。就算收貨登記也就算了，發貨還要7個工作日。這是什麼概念？起碼12天。垃圾的微鯨，再也不買你們產品了 負面 負面
# 4K MEMC，色彩好，擁有HDR技術，廣色域技術，4K MEMC，畫質清晰音質也還好 杜比解碼+DTS解碼，立體環繞音效，搭載酷開系統5.8。再有就是安裝師傅，安裝角度和尺寸，他會根據你家的空調位置和電視櫃還有燈的整體位置效果，來確定你是否滿意放到的尺寸，真的很專業，經過和你溝通好，確定安裝位,而且京東還送了支架，免費的呢！就是感覺電視買小了．總之很滿意！ 正面 正面
# 風行網際網路電視收到已有一週，認真做出一下評價，京東配送效率奇高。農村網點全覆蓋無死角，免費安裝，免費除錯。電視清晰自然，遠超逾期，屬於京東商城價效比最高的電視。操作簡單，內容豐富多彩，老少皆宜的操作風格，風行值得擁有。下次要買就買風行的量子電視。介紹就是高大上。誰看誰知道。 正面 正面
# 看起來還不錯，介面少點，沒VGA口 負面 負面
# 小米電視價效比高，暫時還沒有使用，測試是OK的 正面 正面
# 電視特別好，很清晰，物流也很快，贊一個 正面 正面
# 金屬邊框，背板是塑料的，較厚，價格還行吧，網路還沒到位就開機試了一下，總體滿意 負面 負面
# 已聯絡掛牆安裝完成，服務不錯，就是側面看上去有點厚，但價格確實便宜啊。 正面 負面
# 塌頭，做工粗糙，工具質量差，擰幾下就變形了。螺絲一堆，我就問問怎麼跟安裝說明不一樣，少了4個，客服非常沒耐心！就一句‘’螺絲都一樣的‘’就消失了！我連問三句都沒搭理我！ 負面 負面
# 又11買下的，優惠了一點，外觀蠻大氣的。 正面 正面
# 微信服務號設計有問題無法預約安裝，客服電話佔線打不通。聯絡京東客服，還是推來推去，售後真差！！！！不是一般的差！給一星都多！ 負面 負面
# 非常好 正面 正面
# 感覺很好，12號1點買的，早上九點就送到位，下午售後進行了安裝除錯，很大，家人都很喜歡，支援國貨！ 正面 正面
# 給媽媽買的送貨超級快，免費安裝，送貨人員服務也很熱情，安裝師傅很用心，給媽媽耐心講解，媽媽說畫面很清晰，內容也很豐富，在家裡放著也不大，不佔地方，挺好的電視 正面 正面
# 送貨速度快，剛剛裝好，聲音效果不好，螢幕顯示效果一般 負面 負面
# 畫質還可以 但是語音功能根本不能用 忽悠人 打400微鯨客服 派人過來也是回覆出廠設定而已 失靈時不靈 我主要看語音控制才買的 沒想到只是個噱頭而已 很不滿意 給差評只是對語音來說 其他的都滿意 沒有壞點 另外電視功耗高 發熱量很大 不要相信視屏秀 騙人的 負面 負面
# 物流是真快，但是悲催的是少了底架上的螺絲配件，電視安裝不起來，所以還不知道電視怎麼樣哦，就等著一個小小螺絲配件了，好幾天了還沒到，能快點不 負面 負面
# 電視不錯。主要是便宜 正面 正面
# 差評 很不滿意 當時的活動是送掛架 結果沒送 售後用50來抵 還有問我要當時活動頁面的截圖！ 限時活動還來個限量 負面 負面
# 大品牌 防靜電包裝 值得信賴！ 正面 正面
# 差評，6月1日下單，定的24號送貨，618的時候看到可以送支架，問客服我下的訂單是否送支架，當時想如果不送就重新下個單，客服回覆說送。送貨的時候沒有收到支架，再問客服，客服說根據訂單編號查詢，不送支架，真是暈。第一次問你們的時候怎麼不根據訂單編號來查詢，就直接說送。等送貨了，又說不送，毫無信用可言。 負面 負面
# 東西可以，配送物流對接不好。需望改進。 負面 正面
# 第二次購買，覺得微鯨的電視不錯，資源還算豐富，就是沒有直播，這點比較不滿意，其他都比較滿意！ 負面 負面
# 畫質挺清晰的，便宜 正面 正面
# 挺好的，物流也快，兩天就到了 正面 正面
# 功能方便，體驗還好。價格便宜。 但是螢幕素質不好，左下角嚴重漏光。 負面 負面
# 因房子裝修沒有結束，還沒有安裝試用，電視機通電試了情況良好，售後服務也不錯，啇家服務很好?，等正常使用了再來追評。 正面 正面
# 感覺不錯，價效比不錯，功能挺多，就是遙控器沒有九鍵，有點不開森 負面 負面
# 使用ios對微鯨電視投屏 部分軟體不支援全屏播放。我在家用Youtube對微鯨電視投屏 拿網頁看不全屏可以正常播放，如果點全屏的時候微鯨就黑屏 進度條也不移動過了2~3秒 微鯨就閃退到主介面了。希望技術大大能解決一下，十分感謝！！ 負面 負面
# 利用藍芽智慧遙控器語音操作，識別率高，快捷實用，值得稱讚。微鯨Live裡面有不少4K資源，只是沒註冊會員暫不能觀看，以後再追評吧。客服態度不錯，有問必答。不足之處因為是國產硬屏，色彩的豔麗度不如進口屏；另外USB等外用介面數量偏少了些，使用上稍顯不便。考慮到購買消費群的年齡段，在促銷活動時，如果能贈送配套的遊戲手柄，那麼競爭力無疑會更強。總體好評，值得推薦! 負面 負面
# 第二臺，只不過今年的價格是出奇的高了 負面 負面
# 很滿意的一次購物體驗，京山縣服務店店家耐心負責確保了東西安全到家。以後家裡用的還會上京東購買。 正面 正面
# 電視機播放效果很好，很滿意 正面 正面
# 不錯 正面 正面
# 雙12買的電視～發貨速度很快～第二天就送到家裡了～當時打電話安裝師傅很快就到了～外觀很漂亮～影象清楚！關鍵是前期服務確實不錯～ 正面 正面
# 太讚了！盛傳商城神速，服務好，我本有點懷疑，但是親經歷了，讓我知道，真的就是這麼好。第一天下單，第二天就告訴我能安裝了，這速度，不能再好了，只是我房子沒裝修好，暫緩2天來安裝。客服好講，服務周到，電視大氣，畫質超好，比實體店的4k電視要好多了，風行牌子真是不錯，給個大讚！安裝人員也是非常敬業，非常的棒，一次很好的購物體驗！還沒裝寬頻，裝好了再來續評！ 正面 正面
# 留意微鯨好久了，一直等待活動入手。可惜越等越貴，今年電視全部都漲價了，6月果斷入手。用著還不錯，一到跟兒子一起開啟，他很開心，可以看巧虎，掛架是找了樓下裝空調的師傅打了牆孔，有鑽頭我就自己搞定了 負面 負面
# 質量很好！很高清，畫面細膩，非常滿意！ 正面 正面
# 這個大電視真是太好了 效果非常不錯 買給父母很開心 已經看上了 我家的電視都是這個牌子 正面 正面
# 雖然電視很小眾，但質量真心不錯，比小米電視A4好多了，雖然比不上客廳的索尼大法，但螢幕清晰，色彩豔麗，價效比非常好，關鍵以後還有升級的可能，十分滿意。 正面 正面
# 客服太傻，物流太慢，電視聲音不如以前的小鋼炮 負面 負面
# 個43寸.物流很快三四天就到了.因為新房當時正裝修就改約到20日送貨.物流的服務真好.跟蹤服務很及時值得稱讚.19號電視送到家插上電源試試畫質很清晰.音質也很棒.只是55寸的兩個小時後就黑屏開不了機.打400電話20號來人檢查後開單聯絡客服重發一個電視過來.26號開啟換的電視用了兩天.家裡人都說機器不錯.立體感很強.微鯨電視、電視界的新秀.但願有良好的表現. 負面 負面
# 根本不用預約呀，1198直接買的，非傳統品牌，心情坎坷不安，咬牙下單試試，收貨驗過螢幕沒事就自己裝，4個螺絲而已。頭三次開機好慢啊，最長的幾乎5分鐘，趕緊撥打客服電話，可能是系統更新，後來就好了，待機開機飛快，音畫滿意。總算安心了。連線行動硬碟居然連原盤也能放，強啊！ 負面 負面
# 相當不錯的電視，就是下雨天送貨慢了點，等到晚上才送貨 負面 負面
# 嚴重不滿意。開機也慢。最重要的是沒得誠信，大家自己看，一點信譽也沒得，哪個買了哪個後悔，大家自己看！ 負面 負面
# 簡單，容易操作，不過電腦沒有自帶電視直播軟體，應用商店也不能直接下載，還要找個電腦下載到優盤上，然後再安裝，很不方便。 負面 負面
# 沒有問題，很不錯 正面 正面
# 第一次收到屏裂了，京東馬上換一臺新機重新發過來，贊一個！！ 負面 負面
# 質量不錯，服務太度滿意。 正面 正面
# 第一次在京東買大件，剛開始心裡不大踏實，怕出現意外情況，結果還是挺滿意的，送貨小哥把電視給送到家裡，開箱驗貨，通電聯網，一切正常後才離開，在此非常感謝！電視效果也挺好的，第一次用智慧電視有些功能還沒有搞清楚，送的電視掛件和會員還沒有到位，希望商家儘快安排！謝謝！ 負面 正面
# 價格便宜品質好，螢幕看電視很高清 正面 正面
# 挺好的，是我喜歡的！ 正面 正面
# 家人都喜歡這個電視，索尼還是可以的。 正面 正面
# 還行，但是螢幕感覺顯示有問題 負面 負面
# 內容較多，操作方便，輕薄，不知是否耐用，待觀察 正面 正面
# 點，來的時候都十點半了。開機後，在電視上掃碼註冊賬號，用微信、qq、微信、手機號試了很多次，一提交就顯示空白頁面，換網站操作也一樣。打客服電話，客服只會重複一樣的話，最後還是線上客服微微幫忙註冊的。電視本身不錯，畫面跟音響都可以，連線聯通ip電視、硬碟、電腦都沒問題，播放很流暢。而且介面都在一側，插拔很方便。自己裝的底座，電視太大不是特別穩定，準備換成掛架。 負面 負面
# 老顧客了，東西很好，會回購 正面 正面
# 電視到了，雙十一買的雖然等了很久但是還是覺得很不錯，感謝的送裝服務，電視整體感覺很不錯，色彩還原很好，聲音試了下也不錯，給老人買的應該很適合，速度很快！看了下配置，49寸的完全沒毛病，推薦大家購買 正面 正面
# 本上就是噱頭，沒有宣傳中的那麼好，基本沒有任何改善，黑暗背景下四角全是白光，這應該就是傳說中的漏光吧，omg。再就是背部的散熱口，播放半個小時後能夠明顯感覺到很燙，很燙。再就是遙控器，縮水了，雖說評論後可以得到語音遙控器，可畢竟是遲來的愛啊。作為一個微鯨的老使用者，衝著是對之前產品的良好體驗才來再次購買的，而赤裸裸地標註是品牌高階系列，帶來的體驗確不敢恭維。 負面 負面
# 很快，關機要長按電源鍵再按確定鍵有些麻煩，按一下是待機，京東的送貨師傅給除錯的，服務超好，免費給安裝了底座，除錯了電視，還給幫忙把移動送的盒子也給裝上了，不過掛機連架子要169有些貴了，希望能便宜些，現在電視櫃沒到暫時放地上看著，回頭再喊師傅來掛起來。整體很滿意，希望質量能靠得住~投屏，裝軟體都很方便，送的會員還沒捨得用，客服說一年之內註冊都可以，省著以後用 負面 負面
# 電視夠大氣 畫面清晰 就是還不太會用 正面 負面
# 貨收到，物流還是很給力的，現在試用還可以，繼續關注 正面 正面
# 這電視不錯，價錢便宜，服務一流，辛苦了快遞員，要求加工資。 正面 正面
# 剛剛安裝完，自己安裝的，電視不錯，唯一就是聲音小，重音太輕其他的都不錯。 負面 負面
# 很好的一次網購，快遞速度超快，安裝師傅服務很好，電視開機速度快，音質很優越，這個價格價效比超高，還送三年售後，極力推薦購買。不愧大廠出品。 正面 正面
# 自營家電品質有保證，暴風電視，非常實惠，價效比很高 正面 正面
# 除了開機太慢其他都很好 負面 負面
# 效果不錯很好剛買回來就安裝好了物流也很快 正面 正面
# ，半顆星都不想給，電視無法領取會員客服都無法解決，讓打技術支援電話，打電話給技術支援，態度不錯，告訴我也沒辦法解決，要下班了，第二天再找相關人員解決。電話過程中，旁邊其他客服聊天聲音特別大。 特別是京東回覆客服，完全沒有替客戶解決問題的態度，微鯨客服嚴重需要培訓啊。太失望了，本來抱很大希望的。這臺機器肯定是退貨後從新包裝了又直接發過來的。賬號已經被領取過了。 負面 負面
# 東西還不錯，開箱插電，就是物流22號到的 我24號下午催的商家才送的貨，物流不滿意 負面 正面
# 不錯，還送了一年會員，就是不知道那個wifi訊號不好是不是自己的原因 負面 負面
# 1，4K電視，這個價格價效比太高了。 2，49寸放客廳就好大啊，看電影爽啊！ 3，操作不卡頓，不錯 4，片源豐富，就電影區免費片源中都有太多太多好的豆瓣高分電影，這下看個夠吧。 5，總之非常滿意，價效比之王，誠心推薦！ 正面 負面
# 質量很好，畫面很清晰 正面 正面
# 價效比還不錯，蠻好的，買了好多臺了 正面 正面
# 身，視覺無邊框，25核處理器，2GDDR4+8GFLASH，配置好電視才能執行快；電視外表整體做工還行，擁有HDR技術，廣色域技術，4KMEMC，色彩好，擁有HDR技術，廣色域技術，4KMEMC，畫質清晰音質也還好杜比解碼+DTS解碼，立體環繞音效，搭載酷開系統5.8。安裝師傅，服務態度很好，安裝比較專業，耐心的教如何使用。京東購物是正確的選擇。好評！！！！ 正面 正面
# 電視不錯 物超所值 給老媽買的 很滿意 操作也簡單 畫面清晰 正面 正面
# 很好，不錯 正面 正面
# 送貨速度快，質量有保障，活動價格挺好的。希望用的久，不出問題。 正面 正面
# 幫親人買應該不錯 正面 正面
# 特別好 給爸媽買的 正面 正面
# 已收到貨，服務人員服務態度好 好評 正面 正面
# 物流日日順不錯，我地址寫錯了馬上就送到新的地址，雨太大還多次打電話確認時間，雖然快遞箱子外面溼了，裡面還是好好的，但是快遞沒有幫忙裝支架。電視系統簡潔，希望以後能一直升級，電視音質一般，總得來說價效比高，對電視要求不高的可以買。海獅、長鬚鯨客服服務棒棒噠，不會像其他旗艦問個不停，有什麼說什麼。 負面 負面
# 瘋狂到不睡覺都要搶到它，雙11已經錯過了，這一次怎樣都要買到。哈哈！物流特別贊??????當晚購買，第二天下午就收到貨！！從開啟箱子那一刻已經迫不及待的想開機了。。一開啟，畫面非常驚豔，畫質很好，無邊框確實不錯，馬上把舊款的創維放到一邊去了。。酷開系統挺流暢的，而且可以下載愛奇藝，騰訊等視訊軟體，音質很響亮，4K螢幕一流。非常好。。。現在還在摸索當中，哈哈。 正面 正面
# 電視價格合理.質量和色彩值得推薦 正面 正面
# 畫面不錯非常清晰，圖案也細膩，主要音效很好像安上音響一般的效果，開機時間長一點 負面 負面
# 電視不錯。打了電話以後安裝師傅很快上門。 正面 正面
# 電視挺大的，支架就2顆螺絲放不穩，擺電視櫃上一碰就搖搖晃晃，貓爬櫃子上碰了下電視直接掉地上碎屏了，不退不換，修理費3298元比新買還貴，無語…… 負面 負面
# 　　才幾個月，就出現黑屏打不開的情況，有吧友遇到嗎 負面 負面
# 物流配送到家 質量很好 價格實惠 正面 正面
# 電視機收到了，49寸的感覺也很大，顏色也好，物流很快，也幫我們搬到家裡，安裝師傅態度好，很負責，還幫我們連線除錯電視節目，教我們選節目，這是第一次在京東買這麼貴的電器，以前還不放心。現在放心了！老公也喜歡這電視機 正面 正面
# 送貨快，快遞員還給試了螢幕才走。還沒安裝，用後追評。 正面 正面
# 收到貨開啟試用了一下，畫質挺好的，挺喜歡的！！！ 正面 正面
# 電視不錯，沒有壞點，漏光也基本看不出來，看了下電視劇，有點拖影，網上換個介面就好了，暫時沒試。京東的預約客服真的要給差評，沒經過我同意擅自把送貨時間改到星期五，害送貨大哥白跑趟。這裡要給送貨大哥好評，30幾度的天氣，大中午把電視扛到5樓 負面 負面
# 價效比高，買來放在出租房使用的 正面 正面
# 電視開機可慢，感覺比電腦還慢，有微鯨電視臺，沒有直播的電視訊道，客服態度很是冷淡，說不能自己安裝，必須找他們安裝，還必須掏錢，幸虧買的底座版，不用再額外花錢安裝了，遙控器拿出來不能用，也沒有說明，打微鯨售後電話才解決問題 負面 負面
# 從視覺上不會有那種刺眼不舒服，看多了會頭暈目眩的感覺。 最讓人方便的還是它最新推出的智慧語音遙控功能，它可以根據音色識別，找出相對應的內容，而且可以分辨模糊不清楚的聲音，準確度十分高，不會像平常那樣大部分的時間都浪費在了按遙控器上，錯誤率還高，改正也十分不便。 支援的系統也有很多，反正電視機很不錯，無論是從質量還是服務還是售後都非常棒！是一次完美的購物體驗！ 正面 負面
# 電視比想象中的要大、要好，影象很清晰！ 正面 正面
# 這是第一次在京東買大件電器，結果就是一次糟心的經歷。618下單以後，電視第一次兩三天倒是給送到了，但是我在家裡還沒收到的時候，送貨人員就給我點了簽收的確認，我立馬打電話，他說就在我樓下，先點了沒事。我說萬一通電有問題呢？上來之後開啟之後，電視黑屏開不了機，給客服打電話，廠家教了半天各種辦法都不好使， 負面 負面
# 以前沒聽說過微鯨電視，沒了解過這個品牌，感覺價格合適就下單了，果然沒讓我失望，音響挺棒的，螢幕高清，4K看起來很過癮。 最不滿意的是，電視機不是超薄的，還有一點討厭的是螢幕出現過幾次忽明忽暗，不知道怎麼回事，如果再出現這種情況，我就報修了，總體給好評 負面 負面
# 價格不行，買貴了 虧大了，系統會有些小bug 負面 負面
# 用了兩天，出現了兩次黑屏的現象，換一個試試，可以的話再追加評論來 負面 負面
# 貨己收到，維修標貼損毀，售後說派人上門，結果被忽悠，感覺還行，沒人安裝，自己動手，已經在使用了 負面 正面
# 給老家的親人購買的。 配送速度快，安裝人員和快遞員都很好。遠方的親人很高興！ 正面 正面
# 很不錯，價效比高 正面 正面
# 畫面清晰，音響效果不錯，安裝要加三百塊。。。 正面 正面
# 家裡老電視壞了，索性直接換了，風行(FunTV) N39S 這個感覺價效比挺高，上午下單下午就到了，安裝好聯網一切正常，用一段時間看看，影視資源很多，電影動畫片電視劇更新挺快的，滿意的一次購物。 正面 正面
# 電視很清 ，反應快，還不錯 正面 正面
# 電視很好，比我想象的要大，第一次在網上購買，很滿意 正面 正面
# 送貨相當快。第二天一早就到了。這個電視機在這個價位還是相當實惠的。系統執行還是比較流暢的。整體的效果還是比較滿意的，希望耐用一點，以後不要出問題。打分可以90分。 晒單： 收起 向左轉 向右轉 正面 正面
# 剛開箱試機，螢幕質地很好，畫面清淅度高，功能很全，這個價格很值了！ 正面 正面
# 外觀很漂亮 很清晰 無邊框感覺很大。 正面 正面
# 活動買的，比在實體店買的便宜 正面 正面
# 師傅上門安裝好了，不錯。 正面 正面
# 服務態度簡直就是一坨屎，我7月28日下單，31號才裝好。結果現在8月8號，又送優惠券，又降價，整整少了150多，微鯨客服一句沒辦法就算了。這樣的服務態度簡直差到作嘔。大家擦亮眼睛看清楚了，這樣的服務態度，這樣的產品還能走得多遠？總之一句話，非常不滿意，非常非常不滿意！！！！！！！！！！ 負面 正面
# 安裝 不求人 電視很棒 關注微鯨很久了 正好家裡要換電視 果斷出手了 但是有一個小小的bug hdmi接機頂盒 切出去主選單 再切回來 就顯示無訊號了 只能重啟機頂盒 這有點不方便 希望廠家改進一下 av輸出不能顯示1080p 畫質很渣 這可能跟機頂盒有關 無所謂了 用HDMI就可以了 音效沒以前的Sony好 大法還是大法 無可取代 國產品牌還需繼續努力呀！ 負面 負面
# 差評！ 先不說東西怎麼樣吧 一週前收穫架子也到了 安裝的一直拖拖 好像求著他們似的 直接影響我對微?整體素質評價 簡直是受欺負！ 負面 負面
# 這是一款價效比超高的智慧網路電視機，又是滬深上市公司兆馳股份正規大廠生產的電視機。京東配送速度很快而且支援開箱通電驗貨，安裝人員也很專業。智慧電視機的電視內容是和BesTV合作的，電視內容豐富精彩。很滿意！ 正面 正面
# 電視還不錯，第一次買這個新牌子，音質一般般，清晰度就不錯，支援下國貨。 負面 負面
# 挺好的，就是郵費有點貴 負面 負面
# 00），兩種方案我都不是很滿意。質量畫面清晰度其實我說還可以吧，比起大牌還是差點，為什麼這麼說呢？因為我在家0.5米外看還真有點模糊（沒有近視），有點暗。還有你們跟微鯨公司還是兩個不同公司，並不是微鯨公司的，應該屬於授權，因為我打客服售後他們親口說的。物流也很差，那天來了也是匆匆忙忙就走了，只是讓我趕快檢查螢幕，其它都是我自己安裝，比起第一次的物流真的很差。 負面 負面
# 挺不錯的，家裡都很喜歡 正面 正面
# 物流快，這款機子大氣超薄就是美中不足有點瑕疵屏不直不完美，叫老闆換了一臺就好了，要是圖象再能亮淨點就更好了。 正面 負面
# 畫面很滿意，就是**員區有的電影看不起，還有的只有5分鐘，鬱悶。 負面 負面
# 不錯啊！畫面清楚 正面 正面
# 電視畫質非常不錯，比雙11稍貴了點，不知什麼原因連不上wifi。總體非常滿意。 正面 正面
# 此使用者未及時評價，系統預設好評。 2017-12-25 20:13:54 追加： 小米真心不錯，物超所值 正面 正面
# 電視很清晰，安裝師傅安裝不錯。發貨速度很快，滿意推薦購買 正面 正面
# 價格優惠，質量也好，現在已經裝好了 正面 正面
# v，全金屬外殼，外觀不錯，然而用了不到一天就開始出現黑線，完全失望退掉了。在網上比較再三，因為外形選擇了微鯨，收到手的時候感覺塑料感太重，有點失望，但裝好了以後感覺非常棒，開機乾淨，色彩均衡，清晰度明顯高於暴風，反應挺快，各種設定也是恰到好處，不愧是專門做網際網路電視的。4k片源用的是騰訊視訊，片源很豐富。唯一問題是連線歌華機頂盒無訊號，繼續觀察，希望穩定。 負面 負面
# 我買了兩個風行電視，本來買給老人用的，因為便宜，但是裝好開機以後發現這也太好了吧，價效比很高，螢幕很好色彩很好，尤其是遙控器，特別好，哈哈哈，不錯不錯，以後還買風行吧，片源好像也很多。專業做電是的品牌真心棒！哈哈 正面 正面
# 照片就不晒了，電視機硬體還可以，但是內容方面簡直了，官方應用市場沒一個有用的APP，視訊內容也是非常少，隨便搜個電影bilibili 上早就有了在這裡搜還顯示沒資源呢。電視劇呢，像鄉村愛情故事這種必須要鑽石會員才能看，贈送的白金 會員根本沒用，老哥你也不看看你有幾個資源啊？就想讓使用者買鑽石？真是雞賊的夠夠的了。綜上來說不太滿意 負面 負面
# 京東客服商家客服都好！電視有點問題當天反饋第二天就來換新！售後好！打電話就來！京東值得信賴！ 正面 正面
# 外觀好看，又便宜，挺值的 正面 正面
# 今天收到禮品了。全是全部到了。暫時各方面還不錯。就是送貨的讓我挺生氣。缺點是記憶體太小了。其它的過一段時間來追加吧。 負面 負面
# 快遞員一個人送貨 很辛苦 安裝人員熱情細緻 電視也很好 正面 正面
# 試看了一晚，視訊資源很給力，但系統不太好，開機太慢，？ 負面 負面
# 用了一段時間，感覺還不錯。畫質挺清晰的。感覺還算不錯吧！ 正面 正面
# 電視也就一般沒有說的那麼神奇！客服妹妹態度不好半天沒人應答！微鯨熱線是沒人接電話嗎？打了半個小時沒人接電話～！還好大的那臺沒買微鯨 不然會被氣死～！物流人員態度也不是很好 負面 負面
# 好 挺不錯的 很薄不佔地方 正面 正面
# 一直想著今年雙11入手一臺平板電視的線下實體店線上各平臺糾結了很久最後機緣巧合選擇在京東這裡入手到貨很快簡單安裝後就開始欣賞節目了大螢幕真是讓人歡喜 正面 正面
# 第二臺微鯨，漏光沒大家說的那麼嚴重，壞點粗略看了下沒有！就是螢幕下方中間有一異物，估計是塑料件的毛刺！影響不大懶的換了！曲面看起來並沒有啥特的感覺！還有就是會員略坑，當初199，現在299！還多了個鑽石會員！總體滿意吧！ 負面 負面
# 值得信賴，音質不錯，畫質很好 正面 正面
# 完全是電腦小白，之前一直想買60寸，但是發現55寸的確是最有價效比的，於是就吃螃蟹買了微鯨，暫時放在新家未見面，就收貨試機一睹真容，感覺還是不錯的。聽大家說是硬屏，介面豐富方便拓展，感覺自己是買對了。但是，誰能回答我：到底有沒有廣告？為啥今天來看發現頁面上寫著內含廣告？ 負面 負面
# 電視已收到，還不錯吧，媽媽滿意 正面 正面
# 微鯨電視很不錯，價效比高，速度也挺快，雖然有一個壞點，但不影響觀看，就不換了，希望以後都沒問題 負面 負面
# 非常好，壞了一臺，立馬換新的，售後一流！！ 負面 負面
# 雖然蠻後悔錯過雙十一8000E的活動買了這個，但就電視本身還是很滿意的 正面 正面
# 50寸的好大啊，比想象的大好多，遙控器手感很好，操作簡單，電視很清晰，超薄的一個人就能安裝，送貨師傅很好，送上樓來還給除錯了，贊一個，比商場便宜很多，超值！ 正面 正面
# 幫朋友買的，三星電檢視像清晰，掛在臥室合適。京東自營發貨快，晚上拍第二天上午到，真的好快哦！ 正面 正面
# 清晰度蠻好的 廣告很煩人 送的會員用處不大 很多劇也是看不了的 負面 負面
# 不錯 正面 正面
# 很不錯，買的時候覺得大，安上一點也不覺得大。價格比以前貴了，沒轍，送貨師傅第一時間沒找到總開關，差點送回去，真愁人。 負面 負面
# 一般般。這個價位也不會抱太多的期望。比某某TV還是好很多。 負面 負面
# 很滿意，不錯，物超所值 正面 正面
# 電視不錯，清晰，大小剛合適，家人都很滿意 正面 正面
# 暫時沒發現問題，正常使用，但是在機器頂部有4個黑點，就不退了，不影響使用，但是一個禮拜了到現在掛架還沒送給我，不知道啥原因。音響不錯，但是大概什麼動態的功能後畫面變暗了。 負面 負面
# 很滿意，還沒裝呢，物流很快 晒單： 收起 向左轉 向右轉 正面 正面
# 家人很滿意，我也很滿意，大品牌質量槓槓的！ 正面 正面
# 用了很久了，現在來評論，除了有點漏光，其他都不錯 負面 負面
# 很喜歡小米電現，功能多畫質好，還可以手機操作，送貨快售後服務好 正面 正面
# 別APP平臺，無法播放視訊，售後也說不出所以然，就發了幾句“我們解碼功能強大xxx”廣告詞，不解決問題。太麻煩了我就不退了，但是以後看到這個牌子都會繞道，也會告誡身邊人不要碰這個牌子。 客服像個冷冰冰的機器，對退貨流程不熟悉，叫我打客服電話問。我打電話，那邊讓我到天貓客服問，被踢皮球。說不清楚100元體驗費和退貨費的區別，說不清楚退貨是上門收件還是自己寄件。 負面 負面
# 小米電視機價格不貴，嗯，看著也可以小米的，產品還是可以的，支援小米 正面 正面
# 物流發貨很快，收到電視後自己就能安裝除錯好，畫面很清晰，看了幾天才來評價的，很超值 正面 正面
# 電視給爸爸買的，總體感覺還不錯，就是送的掛架下單說缺貨，過兩天又有了，感覺虧了一個億…??，畫面感還是可以，日常看電視需求足夠，重點語音功能很方便，快進後退再也不用怕一下退過了，送的會員大部分資源都能看，但是299的會員不能看很多美劇，好像要499的才可以，不過我爸也不看，就無所謂了… 負面 負面
# 挺好的，看久了下面底部很熱，售後安裝220元，被兜售一個HIDMI高清線99元，還有58元的有線電視線，一共花了快400塊錢，有點被售後忽悠了，後來網上一看兩根線最多40快！線上給你優惠，線下想法搞你！ 負面 負面
# 看上了 畫面清晰 流暢 服務也很好 買了很久才申請的壁掛 服務好 很滿意 正面 正面
# 的.之前選電視選了好久看得頭疼,小米是很坑的幸虧沒買,選來選去還是微鯨吧,配置需要的都有了,價格也在預算裡,售後貌似也不錯有1年換新政策呢,第一次買這個牌子電視 真心有點忐忑,京東方的硬屏引數還是不給力啊色域只有68%呢,實際看起來也就這樣吧,也許是機頂盒不給力沒有高清訊號效果也就那樣了,會員現在還沒領取 因為還沒搬家過去,等到時候在開通了仔細體驗後在感受吧 負面 負面
# 服務好，質量也不錯，就是安裝費用太貴，後來自己安裝就花7塊錢，總體ok 負面 正面
# 東西不錯，螢幕看上去蠻清晰，比樂視要快些，就是記憶體太小不夠用。 負面 負面
# 這個最重要的顯示屏不很好，是京東方的，沒仔細看，大意了！！！去年50寸的還可以。缺點： 1、影象不是很清晰； 2、音箱系統音質太差； 3、播放影片時不時有卡頓。 4、商家說的纖薄機身僅僅只是一條邊框，電視機根本不纖薄！ 別的目前還行。 負面 負面
# 東西挺好的，還實惠，就是在掛的時候遇到點問題，物流也挺快的 正面 正面
# 不錯 挺好的 就是比去年漲價不少 大趨勢沒辦法 下次要買還會來的 負面 負面
# 很輕 感覺 挺單薄 不過價格也便宜 對得起 這個價格了 正面 正面
# 第二次購買微鯨電視了，第一次去年給爸媽買，還是原裝LG螢幕，用了一年，藍芽遙控，語音功能，系統都非常好用，喇叭聲音音量和音質都比一般電視強，今年雖然漲價了但是通過比較和一年的體驗還是下單了微鯨，試了兩次還是滿意的。 負面 負面
# 物流很快，有事沒有裝，昨天剛裝好，看一晚上，真的很給力的一款電視，簡潔方便的選單，功能齊全還唱了首歌！沒有選錯。 正面 正面
# 電視不錯，沒有壞點，漏光也基本看不出來，看了下電視劇，有點拖影，網上換個介面就好了，暫時沒試。京東的預約客服真的要給差評，沒經過我同意擅自把送貨時間改到星期五，害送貨大哥白跑趟。這裡要給送貨大哥好評，30幾度的天氣，大中午把電視扛到5樓 負面 負面
# 這個心情真是無語了，還沒開始用就又搞活動降價150元，真想退貨。這叫消費者怎麼樹立品牌忠誠度，真是！ 負面 負面
# 送貨速度很快，服務很好！電視送給爸媽，很喜歡！京東值得信賴！還猶豫的朋友們趕快下單吧！ 正面 正面
# 中肯的說整體上還是對得起這個價格的，但音效和畫質都很一般，尤其是音效很是失望，不能用來聽音樂，音質很雜，不知道是不是都是這樣的? 負面 負面
# 送貨快，但是再打微鯨電視安裝熱線時候，熱線服務生直接給你說，要用微鯨自己掛架，如果因為掛架出了問題他們不管。弄得心裡不舒服。還沒用他家電視就在扯皮。感覺不好。 負面 負面
# 螢幕出廠帶有一層塑料薄膜要撕開才能看清楚，螢幕清晰度相當高，看超清格式的視訊就足夠清晰了，這點倒是挺滿意的，據我感官螢幕應該只有72色域，相對更高色域的螢幕稍顯發白，不過這價也不好要求太多。系統流暢度不錯，按著安卓手機的尿性買之前還以為這配置會卡得很呢，看來安卓電視和手機還是有差別的。總的來說，這機子物美價廉吧，就看能用多久了。 晒單： 收起 向左轉 向右轉 正面 正面
# 暫時沒發現問題，正常使用，但是在機器頂部有4個黑點，就不退了，不影響使用，但是一個禮拜了到現在掛架還沒送給我，不知道啥原因。音響不錯，但是大概什麼動態的功能後畫面變暗了。 負面 負面
# 非常不錯的一款電視，三星4k黑晶屏！系統操作流暢BES電視節目提供商，節目資源應有盡有，什麼電影，少兒，體育通通不在話下。最令我滿意的是聲音感覺很震撼。三八久久買的，分了一二期。總體很滿意，不過就是安裝費要了我一百武，說好的免費安裝卻要錢，實在不太爽。還好電視沒問題。先用用看吧，以後再追評。 正面 負面
# 不錯剛開始覺得顏色不好，有點失真。後來發現人機對話功能不錯。就是沒有售後安裝服務這點不太好 負面 負面
# 顯示效果非常好接硬碟播放流暢清晰音效不錯，這是第二臺了價格比去年貴了，值得推薦。 負面 正面
# 電視整體還是滿意，說說不滿意的地方，1電視開機系統準備太頻繁，時間兩分鐘左右，感覺很窩心，2習慣了使用機頂盒遙控器，此電視遙控器不能被學習，如果看機頂盒直播節目就得用兩個遙控器，很不方便。其他因為才使用還沒發現。 負面 負面
# 飢餓營銷，永遠都是搶購的節奏，價效比還是挺高的，至於質量只有用過的才知道！ 正面 負面
# 給家裡人買的，現在電視都漲價了 負面 負面
# 第一次在京東購買電器，8號下單，9號就收到貨了，電視畫面清晰，棒棒的，安裝師付很熱情，服務周全。五分好評 正面 正面
# 貨了，安裝也很快，暫時沒發現什麼毛病，音效確實不錯，不愧是李健創立的品牌，價效比高，操作也簡潔方便，速度也挺快的，各方面還有待考證，就是自帶的安卓看電影電視很卡，老是在緩衝中，另下的就不會。還有螢幕漏光挺厲害的，透光也是，做工還有帶加強，不是全金屬外殼，還有要求會員的片太多，不是會員幾乎看不了什麼東西，你們的會員並沒有這麼值錢，建議買微鯨電視送永久會員！！！ 負面 負面
# 電視價效比還是挺高的，用起來也挺方便。 正面 正面
# 第一次買微鯨電視，看到價效比特別高，所以就入手了一臺，果然物超所值，開機特別快，資源也挺豐富的，而且是硬屏4K解析度，清晰度和色彩都不錯，藍芽遙控器是一個亮點，但是這電視的邊框是塑料的，看上去質感不行，比較廉價，不過這個價位可以理解，希望微鯨電視質量也過硬。 負面 負面
# 雙十一yiqianba買的，剛剛裝上，安裝師傅。。挺好的。加上掛牆支架，一共收了140，還幫忙開通了奇異果會員， 正面 正面
# 第一次在京東買電器，服務比實體好太多，安裝的師傅服務很好，全滿分，下次再來 正面 正面
# 大屏還是狠舒服的，顏色也不錯，沒有4k資源，不知道效果怎麼樣 負面 正面
# 之前買過一臺，都有配藍芽遙控器，這次沒有。再說了，和女朋友買的同款電視，她晒單有藍芽遙控器和貓超卡，而我只有藍芽遙控器，這樣的商家我選擇給差評，以後也不會再買了 負面 負面
# 雖然用了半個多月才送來，但是終於寄來了，價效比算高的了，畫面有待提高 正面 負面
# 真心不怎麼樣，用的聯通的智慧沃家，看電視畫面渣渣的。會員專區裡面的還可以，問題是家人一般看直播比較多。評論沒錯，螢幕邊緣按一下就往裡面凹進去的感覺，沒什麼質感。2288買的，也算了吧。希望大家還是買別的品牌吧，畢竟術業有專攻，感覺前期都是靠低價攻佔市場，收穫這麼多好評。現在漲價這麼多，品質反而下降？ 負面 負面
# 產品本身什麼都滿意，就是有幾點：1.開機賊慢 2.內建應用商店的應用少的可憐 3.影視資源也不算多 4.遙控器比較寒磣都沒有帶滑滾 5.廠家的客服不咋地，一個網際網路企業問點小問題都不專業怎麼立足！ 負面 負面
# 還不錯，挺好 正面 正面
# 今天收到的物品，東西外觀很驚豔，電視比我想象的大！清晰度很好！沒感覺有色差之類的，現在家裡面的網路還沒弄好！看衛視節目還不能看，這款電視比我現在家的電視好很多！對了，送貨很快。表揚下。支援國貨支援風行???? 正面 正面
# 這個電視很還錯，價錢便宜值得一買 正面 正面
# 螢幕還不錯，感覺音響一般，聲音都開到20了，金色邊框感覺粘上去的貼合不夠緊，還沒連網路，以後再來評價內容 負面 負面
# 第一次買創維電視，在58寸和65寸之間猶豫了很久，最後還是選擇了65寸，本來擔心會太大，裝上後效果不錯，12號買的，需要調貨的原因等了幾天15號送到，貨到20分鐘後安裝師傅就來了，創維提供的免費安裝，加了點錢換了個好點的掛架，提醒大家要等正規的創維安裝人員，物流資訊會洩漏，貨沒到就有其他安裝人員電話聯絡要安裝，但要收費，差點被忽悠 正面 負面
# 最差的一次購物，電視機清晰度很差，而且售後和物流也不行。最不滿意的就是他們的物流，找物流公司之前不能先網上百度一下信用嗎？網上一片說他們家物流差的聲音。而且明明沒有到我的收貨地，也沒打電話，說是聯絡我才沒有配送。物流圖能說明一切。申請退款還不給退。 負面 負面
# 剛開機看了，看起來很不錯，沒有壞點，現在55寸電視也是微鯨最便宜了，而且也很好用，就是沒有hdmi線，會員很坑，員299，鑽石會員要499 負面 負面
# 非常滿意 正面 正面
# 畫面清晰，流暢度一般，用了一個多。沒發現質量問題 正面 負面
# 很不錯啊真的很滿意，很不錯。。 正面 正面
# 電視雖然是搶到的 但是看著螢幕不行 太花了清晰度不行 價格也低 湊合看吧 負面 負面
# 很不錯的商品，可以升級的模組，大尺寸電視 晒單： 收起 向左轉 向右轉 2017-12-11 21:56:20 追加： 什麼鬼，假4k，坑die呢 收起 向左轉 向右轉 正面 正面
# 清晰度不錯 音效比一般的電視要好些,色彩有些顏色偏藍 其他的都好.送貨稍慢比京東預計的時間晚一天. 負面 負面
# 寶貝確實不錯，比我以前買的其它牌子還要好的多，一點都不卡，唯一安裝費太貴。 負面 負面
# 物流太慢! 負面 負面
# 還是選擇了微鯨，總體很滿意：一：同等價位的電視這個硬體配置絕對最具價效比，買電視還送了壁掛架子。2G運存加16G儲存足夠用了；還有兩個usb3.0介面比較給力 二：系統使用起來簡單易用，開機沒有廣告。不限制應用安裝。 三：藍芽語音遙控器使用方便，不用對著電視就可以輕鬆操控。在電視設定裡面還可以看到遙控器電量。 最後個人感覺介面再提供一個SD卡插槽就更完美了。 負面 負面
# 客服態度差，產品描述不清楚 負面 負面
# 給父母買的電視 爸媽很滿意 正面 正面
# 電視不錯，物流快，服務態度好，螢幕效果好，音質一般，遙控器手感不錯，對客服巨頭鯨的服務很滿意。 負面 負面
# 好，一次不錯的選擇，非常清楚，非常好。 正面 正面
# 電視機不錯，雙十一的價格也不錯，但安裝師傅的收費與網頁上的價格不同，送貨、安裝是同一個人，不清楚是誰的問題，最後電視機是自己安裝的。 正面 正面
# 很不錯的電視，嗯質感很好，送貨也很快。 正面 正面
# 電視 目前沒問題，問題是買來沒幾天就降價，心裡就不舒服了，搞活動都是套路啊……降價太快了，幾天一降價…… 負面 負面
# 別APP平臺，無法播放視訊，售後也說不出所以然，就發了幾句“我們解碼功能強大xxx”廣告詞，不解決問題。太麻煩了我就不退了，但是以後看到這個牌子都會繞道，也會告誡身邊人不要碰這個牌子。 客服像個冷冰冰的機器，對退貨流程不熟悉，叫我打客服電話問。我打電話，那邊讓我到天貓客服問，被踢皮球。說不清楚100元體驗費和退貨費的區別，說不清楚退貨是上門收件還是自己寄件。 負面 負面
# 一直在用創維，從老式電視就用它了，畢竟是老牌子。值得信賴。買回來家人都喜歡。 正面 正面
# 幕質量一般，只能說勉強對得起這個價格，整體做工還需要改進。 資源上，基本上都是騰訊的，並不豐富！經常感覺還是切換到機頂盒看聯通iptv好了！ 軟體上出現一次進去點播時突然黑屏問題，長時間都不能恢復，也沒有反應，只能斷電重啟。 ps今天發現u盤識別問題，插著U盤開機後，發現插拔後再也不能識別U盤！ 再說說物流吧，日日順物流是非常快的，驗貨時配送師傅都比較著急。 負面 負面
# 不錯，跟描述的一樣，很好用也很給力 正面 正面
# 有點小劃痕，不影響使用就懶得換了，其他的滿意。。。希望質量好能多用幾年。。？ 負面 負面
# 這次買了兩臺，去年買了一臺，效果很不錯，不用機頂盒，簡潔多了，就是會員太貴…… 負面 負面
# 買來做顯示器用的，除錯一下後能用，解析度低就地點吧 負面 負面
# 非常棒！很好，這次的電視很好沒什麼毛病。京東的售後服務還是很給力的！ 正面 正面
# 第二次購買了，相當不錯的電視。很喜歡…… 正面 正面
# 電視真的很棒！，畫面音質都很滿意，那個叫什麼何先生快遞員也很負責人，雖然只是負責送貨，但是我不懂怎麼使用，他會很耐心給我講解，很樂意耐心地為我解答，比小米客服棒多了，小米客服一句話就叫我換，不負責任！不多說，五顆星！ 正面 負面
# 電視到了，螢幕真的很清晰，送貨小哥也不錯，秉承京東規定吧，讓坐也不坐，圖片是用螢幕大師測試的，很好，沒有壞點，反應靈敏，看差評說開機時間太長，我試了一下，只是在斷電重啟會長一些，這屬於正常，沒有開機廣告hin好，就是送的掛架太少了，沒趕上。。。 負面 負面
# 喜歡的網路動畫不用開電腦看了。會員可以用藍光品質播放，細節很到位，這個需要自己設定，它預設的是高清。 2.說下建議 因為是大屏高分，所以部分第三方手機應用閃退不支援，比如慕課網，嗶哩嗶哩等。還有一個就是螢幕封裝有點縫隙。這幾個希望改進。期待新系統的推送。 3.對了，什麼當貝市場呀，自己裝一下，還有HDP不錯。 想看高清還是裝個數字電視機頂盒吧，網一卡真的跪了 負面 負面
# 電視和描述的一樣，畫質比較清楚。就是遙控器與電視連線藍芽的時候費了不少周折，還好，都是小插曲。弱弱的問一句，你們的遙控器和電視連線藍芽的時候好連線麼？希望以後能一切順心！後期我再追評哈！ 負面 負面
# 畫質清晰細膩，顏色靚麗，物有所值。送貨速度快，服務很周到。 正面 正面
# 好給力！顏色鮮明，值得買！ 正面 正面
# 質量好，畫質清晰，不錯 正面 正面
# 給父母買的，開始一萬個不同意，說家裡電視多，但是都是老款的大屁股電視，還小。先斬後奏買回家，都覺得挺好的。 正面 正面
# 材質很一般，輕飄飄的，不結實 負面 負面
# 買過的，我是2988買的，買貴了。5.1價格現在價格一個月掉了100多還送東西。這個還會掉。望買的使用者考慮一下。這個最先是賣2499元的。價格不地道。。。。。啟動慢，，，十幾天了，，每次開機4-5分鐘左右。。。聯絡客服說是升級，我是最新版本了，不知道還怎麼升，，，如果買這個電視，開機可以先開洗完澡再看，，，慢，，記憶體也不足。，，，反正一個字不值當的東西。 負面 負面
# 電視還可以，關注微鯨很久了，價格遲遲下不來，等不了了，音效可以，不過這個語音遙控有點雞肋，功能太少，基本只能換個聲什麼的。 負面 負面
# 質量不錯沒彎曲也沒漏光，就是片源不支援4k 負面 負面
# 第三次買微鯨電視了，雖然比上一年價格貴了一些，但是同比的價格還是比較實惠的，我們把它作為教學的使用，網際網路電視的優勢還是相當大的。 負面 負面
# 不錯，效果挺好，音質也不錯，操作簡單，就是聽說遙控器願意壞，我同事家的遙控器就壞了，不過店家同意免費調換，客服挺熱情，就是總是有上句沒下句。 負面 負面
# 自營購物體驗非常好，送貨快！ 正面 正面
# 安裝 不求人 電視很棒 關注微鯨很久了 正好家裡要換電視 果斷出手了 但是有一個小小的bug hdmi接機頂盒 切出去主選單 再切回來 就顯示無訊號了 只能重啟機頂盒 這有點不方便 希望廠家改進一下 av輸出不能顯示1080p 畫質很渣 這可能跟機頂盒有關 無所謂了 用HDMI就可以了 音效沒以前的Sony好 大法還是大法 無可取代 國產品牌還需繼續努力呀！ 負面 負面
# 對微鯨有些失望，畫質沒有想象的好，會員也看不了啥 負面 負面
# 執行速度挺快的，價格絕對合適，物流運送也不錯，因為是鄉下還給送到家，但是安裝居然收費30元，我們是在盒子裡拿出來，插電聯網就安裝完了，不用掛壁的。整體不錯 正面 正面
# 整體效果不錯 正面 正面
# 畫面非常清晰，音質感也很好，外觀看著挺大器的，總之收到寶貝很開心稱得上是物美價廉 正面 正面
# 使用了兩週，效果不錯 正面 正面
# 之間猶豫了一下，相同配置，到手後發現金色非常大氣上檔次，有一點要提就是買電視不僅僅是買配置了，節目資源的整合也是挑選電視的50%，而資源內容方面瞭解之後微鯨做的還是很不錯的，然後就根據空間情況選購。總之這次購物體驗還是不錯的。一開始物流配送發錯了貨，折騰了兩天，昨晚收貨，接電開機註冊成功，今天看了一下，暫時沒遇到的問題。就電視本身來說我還是比較喜歡的。好評！ 負面 負面
# 為什麼電視機聲音一會大一會小，螢幕顏色不夠鮮豔，有點暗，鬱悶，上京東第一買就這樣 負面 負面
# 還行，但技術比較差，市場應用程式太少，且大多數不實用！！！手機投屏總是連不上！！！ 負面 負面
# 電視質量一般，看電視有點卡了 負面 負面
# 微鯨電視黑屏，售後各種服務態度差，官方微博居然拉黑我？這就是你的員工？@微鯨 @微鯨客服 @李懷宇 你的員工素質真的差。 負面 負面
# 寶貝很好！海爾售後服務態度一流的棒！信賴京東，信賴國產大品牌！買電器上京東！ 正面 正面
# 雙12下的單，今天上午就送到了。電視已安裝好，清晰度還不錯。長虹電視，值得信賴！ 正面 正面
# 卡，慢，宕機，閃退 負面 負面
# 不錯！TCL國貨老牌子，值得信賴！??? 正面 正面
#  系統啟動速度比想像中快多了，開機後畫面顏色很鮮豔，音響效果也不錯，開機就連網把系統更新了，不知道為什麼要更新兩次，系統操作比較流暢，操作得快的情況下偶爾會有卡頓。遙控器手感很好。 電視wifi是不能關閉的，其實完全可以象手機一樣做個wifi開關功能並不難吧，用機頂盒的時候完全沒必要開著wifi一直搜尋訊號，又費電又影響wifi模組壽命，希望這條廠家能看到。 負面 負面
# 用了兩天，介面互動性很好。 送了微鯨一年會員。 和騰訊合作有一些片源。 自己可以安裝很多應用。 可以看英超了。 唯一的問題：有時候看藍光會卡，可能是電視的WIFI模組適配有問題 負面 負面
# 不錯喲 正面 正面
# 很好，質量不錯，影象清晰。很不錯！！ 正面 正面
# 電視是寄給我爸媽用的，我沒看到。但是老媽說音響有點差。快遞小哥人不錯 負面 負面
# 開箱就有質量問題，辦理退貨程式超級複雜，售後超級的爛，天貓旗艦店客服服務也超級的差，以後不會在購買微鯨的產品了，服務差，蝦米客服服務最差，問問題不吭聲，不回答 負面 負面
# 再加上這家店是代銷店，價格補差都補不了的，大家記得看好官方店再購買。 贈送的遙控器和掛架，也是要催了才給發的。不去催，它就不給登記，不登記就不會發的。 申請售後，說重新拍也被拒絕了，這次就算倒黴了，兩臺電視損失了1000元，以後再也不會買微鯨的東西了，微信朋友圈上也跟大家講講這個品牌的事蹟，和極差的市場運作。 體驗極差，以後再也不會買微鯨的東西了。服務不好。 負面 負面
# 小米電視，新國貨，給力，屏大，價效比高，雙十一搶的，貨源緊缺，一九九九應該很實惠了 正面 正面
# 價格便宜，就是開機有強制廣告，看著效果還算不錯。 正面 負面
# 沒有廣告，只是稍微等個十多秒 負面 負面
# 畫質不太好，亮度不夠，對比度不高，像是雜牌貨。 負面 負面
# 小米電視影象很清晰，功能很強大操作也很方便 正面 正面
# 昨晚下的單，今天就到了！唯一有點不滿意的是安裝還得預約微鯨客服，就不知道什麼時候過來安裝了。 負面 負面
# 我覺得這是一款，價效比非常高的32寸電視，根據它的配置，外觀，顏值，使用率，反應速度，都非常非常滿意，而且價格不高，比傳統品牌，要好，有好處不少，只是行動，支援京東，支援京東快遞 正面 正面
# 感覺很好，價效比很高。 晒單： 收起 向左轉 向右轉 正面 正面
# 看球時畫面比較清楚，有輕微託影(小遺憾，畢竟我看電視主演就是體育)，體育資源不是狠豐富(我沒找到西甲,有點吹毛求疵了，還不知道其它能不能看直播)。總體感覺：因為我對電視的要求不高，主演看球，一天體驗，感覺還是買到了自己想要的電視,這個價位來說比較值。微鯨作為年輕的網際網路電視來說是比較用心的，一些小細節希望還需努力用心！最後要說京東物流，轉天上午送達，給力！ 負面 負面
# 原來的壞了換新的 負面 負面
# 物流及配送師傅比京東服務好，幫我安裝好底座通電試完無問題才走。電視接機頂盒很清晰，比小米4A強;網路視訊也很清晰，看藍光無壓力。不足之處：很多熱門視訊要SVIP才能看，語音比小米差得不是一個檔次。另外1元預約贈送的掛架會員之類不知什麼時候到貨。 負面 負面
# 電視很不錯。物流也很快，目前還沒有好的4k片源，所以目前來說還是不錯的。 負面 正面
# 風行電視很漂亮也很超值，這個價位還送會員買到就是賺到，物超所值！快來搶購啊，清晰度沒問題大家不要質疑，正在用沒發現問題，售後和客服加上買的不擔心。妥妥用不怕用壞。會推薦別人來買的。我已經是風迷了。 晒單： 收起 向左轉 向右轉 正面 正面
# 老品牌，我信任，看著不錯啊。 正面 正面
# 爸媽超級喜歡，迫不及待的安裝上了，清晰度好美觀大方，客服更沒的說，商家剛發出貨，我這邊就按錯了，確認收貨了，很擔心的，怕收不到貨，客服一路給我發貨物已到什麼地方，不必擔心，信譽一級棒， 正面 正面
# 寶貝送到了，物流很快，給力！ 正面 正面
# 電視機不咋地，畫質、音色都不好，服務態度也很差。 電視買了能有20天了，到現在發票還沒給我開出來，說是財務統一開發票，一問就是正在溝通中，請耐心等待。不知道要我等到什麼時候，需要買電視機的朋友，不要輕易相信這家店，購買別的牌子好了，有種被欺騙的感覺。 負面 負面
# 一直觀注風行電視，真的是價效比超高的電視呢，不僅外觀精緻，而且螢幕清晰執行流暢，電影片源也比較新，覆蓋了所有熱門的電視劇和電影，小寶喜歡的動畫片也很全，還有美食和養生的節目，真的非常棒，風行真的值得推薦，實物比圖片還要漂亮，送貨速度也很快，上門安裝我很滿意，售後服務一流，非常棒的賣家謝謝 正面 正面
# 送貨員，非常給力，一直等到除錯好才走 正面 正面
# 影象不清楚沒有用幾天就壞了 送貨慢的老火 負面 負面
# 最垃圾的電視，無線網路經常連結不上，我家網路完全正常，其他電視或者手機電腦的wifi無線連結一直正常，售後垃圾，安裝師傅軟體安裝一半承諾第二天來繼續安裝，之後就沒來了，客服售後的解決是 ：也沒辦法聯絡他們當地這些零零碎碎工程師 負面 負面
# 試看了幾天，感覺沒有想像的那麼好，微鯨會員的資源太少了，畫面還算清晰，物流很快，總體感覺沒有達到心裡的預期，語音搜尋有限，不知道能用幾年， 負面 負面
# 剛收到貨，看著很不錯，用一段時間再來追評 正面 正面
# 一般吧，太厚了，架子也夠厚，無線連線老是斷 負面 負面
# 買的第一臺微鯨電視 感覺很不錯 系統很流暢 清晰度也可以 就是個人感覺遙控的時候會有短暫的延遲 外觀各方面還是感覺挺好的 這個價位價效比還可以 負面 負面
# 物流快，電視不錯，其中一個遙控器語音不行 負面 負面
# 臺電視時的客服都是搶著回答問題和服務的，可是還沒到兩年，好像微鯨的初心變了，每次和客服交流對話都是和像機器人一樣死板。做為客服無法為客戶帶來好的體驗，這是作為客服的悲哀。但是微鯨的電視質量還是有保證的，拿了那麼多臺電視機，就只是壞個了搖控，畫質和色彩也還行。就是現在漲價漲的厲害。再一個是二代的電視的腳比一代的不方便。最後祝微鯨越來越好，成長的同時別忘了初心。 負面 負面
# 在618選擇了微鯨。首先，京東發貨確實挺快的，但是送貨有點噁心，差評。其次，送貨不影響電視機的質量，拿到當晚就試了機子，投屏，華數，下載keep健身APP，會員看電影，都很流暢，開機速度確實有點慢……只能歸結於智慧機吧。而那些杜比4k什麼的還沒那種特殊要求，平時看看電視電影已經足夠了……618活動也很划算。最後希望會員可以看更多電視電影咯，機子持續好下去咯。 負面 負面
# 本上就是噱頭，沒有宣傳中的那麼好，基本沒有任何改善，黑暗背景下四角全是白光，這應該就是傳說中的漏光吧，omg。再就是背部的散熱口，播放半個小時後能夠明顯感覺到很燙，很燙。再就是遙控器，縮水了，雖說評論後可以得到語音遙控器，可畢竟是遲來的愛啊。作為一個微鯨的老使用者，衝著是對之前產品的良好體驗才來再次購買的，而赤裸裸地標註是品牌高階系列，帶來的體驗確不敢恭維。 負面 負面
# 然發現了微鯨。對比了下，比小米樂視價效比高，硬體配置更高，原來買過kktv，但是對比後發現微鯨更好價效比高，雖然價格貴了一點點，但是得到了更強的硬體，所以果斷選擇，在618期間果斷下單。很快到貨，拆開後很驚豔很漂亮，掛到牆上高階大氣上檔次，開機流暢，遙控操作方便，UI很方便，畫面細膩顏色鮮豔，總之一切到目前都很滿意，大大的贊一個，推薦想換隻能電視的朋友購買。 負面 正面
# 開機需要5分鐘以上，致電客服，說系統需要更新3～5次，什麼系統一次更新不了嗎？為什麼上門安裝的師傅沒有告知？ 負面 負面
# 非常好，非常喜歡，有沒有會員，送我們一個 正面 正面
# 一開始對商品抱以極大希望，但是物流速度實在不敢恭維，說七天到就七天到太守誠信！商品暫且不說，我只想說這物流，這速度，也沒誰了。就這物流速度，能回頭的顧客不敢相信能有幾個！給物流差評。 負面 正面
# 電視造型還可以 其他的就是渣渣 貪便宜 吃大虧 要買還是買老品牌啊 這電視的畫質我是服了 垃圾中的戰鬥機 關鍵是 反應慢 宕機讓人受不了 這就是質量不過關 每次都要關機重啟 準備下手的小夥伴 慎重啊 不要再被忽悠了 千萬不要貪便宜 負面 負面
# 感覺還是不錯的！我最喜歡紅色邊，和音響，但總得來說比想象的小，當初應該買65得了！很不錯！用著看，不知道售後如何，只有出了問題才知道，退款還未收到 正面 正面
# 一分都不想給，京東這次讓我太失望了，買的電視沒有聲音，說是退貨上門取件，規定好的時間不去，一直拖著，聯絡客服，客服也不迴應，千萬不要相信京東自營，說的特別好，做起事來，你就知道了，這次真是太失望了！ 負面 負面
# 物美價廉 正面 正面
# 剛裝好，開始用，很多節目都要買會員。小米官方旗艦店說送兒童會員月卡，不知道有沒有？ 正面 正面
# 京東家電正品低價服務到家 正面 正面
# 貨物送到，物流非常快，非常好。 正面 正面
# 很喜歡的一款電視，畫質清晰，音質優秀，勝價比跟同尺寸的絕對無敵。 正面 正面
# 鬼迷心跳買了微鯨這個破電視。質量非常差，剛買就內屏爆裂了，開機特別慢，wifi超級不穩定。宣傳講的一年內只換不修全是騙人的。上當後才瞭解到微鯨電視是TCL代工生產的，上門來我家處理的售後是委託海信電視的，完全沒有保障，徹底是一家垃圾公司。大家可以上網查一下，無論電視機質量還是售後評論查的貼子比比皆是。這是本人真實的教訓，大家千萬不要買。 負面 負面
# 電視不錯不錯 正面 正面
# 這價錢超值，收到貨馬上裝上看了一下。很清晰式樣也蠻好！贊贊…… 正面 正面
# 送貨快，介面清楚晰，超窄邊框，功能齊全，家人都喜歡 正面 正面
# 幫朋友買的，非常好我看著都眼饞感覺還不錯我都有點兒後悔當初沒給我們家買了。朋友是讚不絕口啊邊框窄到幾乎沒有看著都非常美觀大氣上檔次高大上，價格還不貴物美價廉微鯨這個新生的品牌兒。看起來樣子真的不錯系統體驗應該也不錯，畢竟是騰訊的資源和合作的只不過安裝的有點兒多事兒。在我朋友家人面前有點兒多嘴多舌的。 負面 負面
# 沒有想像的好，畫質一般，音色也一般般。 負面 負面
# 價效比最高55寸之一，值得入手。發貨速度迅速。腳架安裝很方便。開機直接升級了系統，開機時間稍長，沒發現有惱人的開機廣告。AV埠設計是個亮點。機身有光纖輸出，有迴音壁的同學耳朵可以享福啦。 負面 負面
# 解析度太差了，遠處都看不清。 負面 負面
# 物流快，價格低廉，適合老百姓，信賴，支援！ 正面 正面
# 畫質真的好 音質也可以 正面 正面
# 電視機質量不怎麼樣，一個55寸的半年不到螢幕壞了，之後換了一個新的又出現網路連線不上的問題，每次都得回覆出廠設定才行，建議大家買之前考慮好。 負面 負面
# 電視不錯，清晰度音色色彩度都很好，值得擁有，夏普值得信賴，好品牌就是好 正面 正面
# 安裝及時到位 正面 正面
# 這個電視真是買值了，遙控反應特別快，看4K電影特別流暢，領了免費的兩年會員後，基本上影院剛下架的熱門電影都能看，開4K後有種電影院看電影的感覺。但是這垃圾快遞我就不想說了，省內發貨，第一天下訂單，第四天才到，這種距離我騎自行車都能這個時間趕到，感覺就好像在故意拖延時間，比方說上午7點半到達信陽，下午20點半才從信陽出倉，莫名其妙 負面 負面
# 電視機不咋地，畫質、音色都不好，服務態度也很差。 電視買了能有20天了，到現在發票還沒給我開出來，說是財務統一開發票，一問就是正在溝通中，請耐心等待。不知道要我等到什麼時候，需要買電視機的朋友，不要輕易相信這家店，購買別的牌子好了，有種被欺騙的感覺。 負面 負面
# 感謝京東這次換貨十分順利，雙11買的貨當時沒有仔細驗貨，年前開箱，發現箱子破損，然後裡面的螢幕碎掉，立馬給京東打電話處理。相信京東，沒有錯 負面 正面
# 好評，物流很快顯示18號收到貨，17號早上送到，安裝人員安裝，師傅特別熱心熱情，拿回來之後感覺驚呆了！電視螢幕超大，65寸的非常驚豔，開啟電視機感覺螢幕十分清晰，而且最主要的是電視非常便宜，價格實惠，這個價格能買到65寸的電視非常驚喜，期待風行電視越做越好！！ 正面 正面
# 畫面挺清晰的，該有的功能都有了，而且是高配，就是聲音有點失望，相比5年前買的sony差不是一點.支援國產，仍需努力. 負面 負面
# 除了開機慢、電影資源少且港片無粵語版外，其它還可以，價效比較高 負面 負面
# 東西很棒超值 正面 正面
# 板不詳，記憶體2G，8GROM，還有廣告，算了。 只有微鯨，明確了2G記憶體16G ROM，IPS面板（大概是國產吧，稍微遺憾）。於是果斷下單了。 收到商品，第一，系統流暢，不卡，和同樣2G 記憶體的樂視S50 AIR一個天一個地，贊。第二，螢幕，無壞點，贊。第三，亮度均勻性差一點，這個有點遺憾。第四，片源很不錯，比樂視這個搞笑的片源越來越少的強幾百倍，贊。 負面 負面
# 了一下，網上評論還不錯而且測評表現比同配置的要好價格也不貴，正好818有活動於是直接下單，19號中午收到開機試過正常，做工中規中矩，影象畫質不錯開機較快會員註冊使用方便，唯獨喇叭音效輸出實在太不理想看來要接外接音箱。因為沒買掛架暫時放電視櫃上使用。看了一下背面掛架尺寸為20*20，背面介面在側面接各種資料線還是比較方便的。先寫這些，過段時間看看效果再來評價。 負面 負面
# C,相當良心，所以還是選了創維。四、電視也今年5月份剛上市，雖說對電視沒有多大瞭解，都是網上檢視，電視用的cpu也是去年新出（至於好壞我也不懂，看了很多，大家可以自己檢視）五、對供應商客服很滿意，糾結了好幾天，有什麼問題都問到供應商客服，而且每次都是耐心及時給回答，對於這點體驗很好，相信售後也很給力的。安裝也相當給力，當天下午到貨，晚上就裝上了，還免安裝費。 正面 正面
# 垃圾中的戰鬥機，新機到手，通電後，閃一下就開不了機了 負面 負面
# 55寸電視看起來就挺大的，看自帶的軟體節目挺清晰，第一次開機有點慢，以後都用遙控器開關機還是挺快，第一次用智慧電視，家人都說挺好的，5分好評。 負面 正面
# 聯絡客服要了微鯨送的掛機。微鯨電視在產品本身、客服、運輸安裝上都很不錯，為什麼非要在一個小小的掛架上做這樣的文章呢？讓人感覺不是很舒服，其實完全可以一百分的使用者體驗，這樣只能給到95分。我寧可商家沒有這個贈送掛架的活動，我會自己選擇花錢購買！！！！！！！！！！！不知道其他使用者有沒有這樣的感覺！這算是細節嗎？？你想要讓大眾接受一個新的品牌這樣應該有問題吧！ 負面 負面
# 電視整體不錯，送會員、禮包，價效比挺高。畫質清晰，整體厚度也挺薄，就是螢幕與邊緣的縫隙比較寬，寬的我都無力吐槽了。看了一段時間，期間出現過倆次遙控器突然失靈，最後重啟電視恢復，不清楚怎麼回事，諮詢客服讓恢復出廠設定，恢復後暫時沒有失靈過。我想應該是系統問題，望以後優化。客服回答問題及時，雖然專業問題回答的不夠專業，但服務態度挺好。 負面 負面
# 家裡買的第二臺微鯨電視了，一如既往的好用，資源也是夠多的，對比了樂視小米，最終還是選擇了熟悉的微鯨，趕著618活動價趕緊入手，就是12號0點十幾分下的單，說掛架送完了，白天我再看了一下又有送掛架。我就鬱悶了。 負面 負面
# 螢幕嚴重漏光 換貨故意推遲 故意推脫時間不發貨，大家購買慎重 負面 負面
# 鯨的，我買電視的準則是在能使用的基礎上考慮價效比。雖然不是很懂，但對比了一些硬體引數，再加上做活動，以試試心態下單了。 現在使用過了一段時間，感覺畫面還行，卡頓也不明顯，作為電視的功能是能勝任的。至於安裝app就沒怎麼用了。順便提一句，圖裡面IPTV那個介面提示升級是指機頂盒，開始沒搞明白以為是要升級電視的作業系統，搞得拿電視的藍芽遙控器狂按沒反應， 汗一個 負面 負面
# 電視挺好的，暫時沒什麼問題，反應有點慢，記憶體加1g就完美了 負面 負面
# 看來一陣，說說感覺，4K感覺很清晰，資源的話如果裝個小鷹直播 再來個愛奇藝會員，那基本上啥都有了。不足的地方就是漏光很嚴重，看電影的話 上下兩條黑邊很明顯的發亮。喇叭質量太一般，接個小音箱後感覺好多了。目前就這麼多，其他如果有特別的會追評。 負面 負面
# 老闆摳死了，連個掛架也不送，買完搞活動送掛架，買時也不說要搞活動，啃爹呀，坑爹，這個43的4K清晰度不如之前的50A的而且亮度也不行，偏暗，側面看厚，總之這次購買不如上次，相差半年多，價格也漲了不少，可能是品牌知名度高了，行大欺客呀！ 負面 負面
# 送貨很快，師傅來了就按照我們的要求直接把電視掛牆上了，非常好！ 正面 正面
# 很好，很清晰，顯示屏很大 正面 正面
# 雙十二買的發到鄉鎮 沒想到這麼快就收貨安裝了 安裝師傅很專業 講解很細緻。電視外觀漂亮 窄邊設計顯得螢幕更大，畫質清晰 比一般4k電視色彩更豐富，智慧介面簡潔易操作，風行資源夠多，也可以自己下載軟體。風行網路資源沒得說電影電視劇 少兒節目都很多而且操作簡單 老人學起來都很方便，買之前對比很多隻能電視 現在看來風行物有所值！ 正面 正面
# 價效比不錯 正面 正面
# 物流太差了，本省的配送點走了5天，服務態度不是很好，習慣性好評 負面 負面
# 貨品已經收到了，色彩挺好的就是沒有之前買的45寸的價格實惠，但是跟實體店的價格比便宜多了 正面 正面
# 電視剛買回來的時候那段時間遙控器經常失靈，有一會可以一會又不行，申請師傅上門安裝師傅打電話給我你要安裝調什麼，無語我要是全能要你們幹嘛？搞的來火自己解決，微鯨售後服務是不咋地。 負面 負面
# 因為我自己雙十一買了臺55寸的、覺得很不錯、雙十二給哥哥買了臺43寸的、原本想買49寸的、結果49寸當天停售一樣的、浙江台州、武漢全沒貨、沒辦法就買了43寸的 正面 正面
# 置卻不低。送貨快，快遞員幫著開箱檢查，沒找到什麼毛病，螢幕色彩亮麗無壞點。再說缺點：有了電腦的效能就有了電腦的毛病，開機慢（15秒左右），有一次開機居然還宕機了。沒有vga介面。螢幕反光大些。用料差些，看那單薄的電源線和插頭就知道了。最大的糟點還是聲音乾巴刺耳，就好象音箱只裝了高音而沒有中低音喇叭，而且機器沒有外接音箱口。當然一分錢一分貨，也不好再多挑剔了。 負面 負面
# 電視不錯，價效比超高，雖然沒有雙11划算，但已經很超值了 正面 正面
# 昨天晚上下單 今天下午收到電視機 自己安裝上底座 直接連線的wifi沒有接機頂盒 操作很方便 百視通的影視資源足夠豐富 喜歡看的影視劇和綜藝都有 電視機色彩豐富 執行記憶體雖然不大 但是我覺得沒必要安裝第三方app 所以使用上沒問題 總之很滿意的一次購物 晒單： 收起 向左轉 向右轉 正面 正面
# 給家裡老人買的，很不錯哦，價格實惠 正面 正面
# 給父母買的，特意用了一段時間再來評價，電視非常好，沒有壞點和損壞，介面也很簡潔，便於操作，稍微不足就是開機會比普通電視慢一些，這應該是智慧電視的通病吧，如果可以希望微鯨大大可以更新系統優化下開機時間~電視真的很棒，價效比爆棚，值得大家考慮購買。 客服很細心，快遞小哥很耐心的等我通電驗貨，態度非常好。 負面 正面
# 長鬚鯨和海獅回答都很及時，雖然物流不夠快但是服務不錯電視不錯，對比了樂視小米和微鯨論價效比還是微鯨好點 負面 負面
# 所以看不到4k效果，但是應該可以。 自帶音響，中規中矩吧，好像沒有別人說的好。而且，到現在沒連線上我的漫步者，這個非常不滿意，因為看到網上說好像普通3.5mm的連不上或者連上了聲音小。希望廠家接下來開發的電視有改進。不知道我要不要換個音響。其他的用用再說。 放在地上的是跟我混了兩年的tcl，天氣受潮，修了一次，下崗了。 最後，我也覺得底座不算太穩，湊合著用。 負面 負面
# 電視機一般，低端機不要求那麼高咯。 負面 負面
# 很好，兩點下單上午就到了，服務很好。 正面 正面
# 幫朋友買的，好好好好好好好好 正面 正面
# 模型在測試集上的準確率為: 0.9254079254079254.

# %%
#預測結果
# -*- coding: utf-8 -*-

# Import the necessary modules
import pickle
import numpy as np
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences


# 匯入字典
with open('word_dict.pk', 'rb') as f:
    word_dictionary = pickle.load(f)
with open('label_dict.pk', 'rb') as f:
    output_dictionary = pickle.load(f)

try:
    # 資料預處理
    input_shape = 180
    sent = "自助點餐機 會慢了點。晚上無打洋"
    x = [[word_dictionary[word] for word in sent]]
    x = pad_sequences(maxlen = input_shape, sequences = x, padding = 'post', value = 0)

    # 載入模型
    model_save_path = './corpus_model.h5'
    lstm_model = load_model(model_save_path)

    # 模型預測
    y_predict = lstm_model.predict(x)
    label_dict = {v:k for k,v in output_dictionary.items()}
    print('輸入語句: %s' % sent)
    print('情感預測結果: %s' % label_dict[np.argmax(y_predict)])

except KeyError as err:
    print("您輸入的句子有漢字不在詞彙表中，請重新輸入！")
    print("不在詞彙表中的單詞為：%s." % err)
# Out:
# WARNING:tensorflow:7 out of the last 435 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f473a2c04d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 輸入語句: 自助點餐機 會慢了點。晚上無打洋
# 情感預測結果: 負面
