# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Dropout, LSTM
from tensorflow.keras import losses, optimizers
from tensorflow.keras import regularizers

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#運用pd讀取資料
milk = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/monthly-milk-production-pounds.csv", index_col = 'Month')
milk.tail()
# Out:
#          Monthly milk production (pounds per cow)
# Month
# 1975-08                                       858
# 1975-09                                       817
# 1975-10                                       827
# 1975-11                                       797
# 1975-12                                       843

# %%
#運用pd Datetime讀取資料
milk.index = pd.to_datetime(milk.index)
milk.head()
# Out:
#             Monthly milk production (pounds per cow)
# Month
# 1962-01-01                                       589
# 1962-02-01                                       561
# 1962-03-01                                       640
# 1962-04-01                                       656
# 1962-05-01                                       727

# %%
print(milk.index)
milk.index = pd.to_datetime(milk.index)
print(milk.index)
# Out:
# DatetimeIndex(['1962-01-01', '1962-02-01', '1962-03-01', '1962-04-01',
#                '1962-05-01', '1962-06-01', '1962-07-01', '1962-08-01',
#                '1962-09-01', '1962-10-01',
#                ...
#                '1975-03-01', '1975-04-01', '1975-05-01', '1975-06-01',
#                '1975-07-01', '1975-08-01', '1975-09-01', '1975-10-01',
#                '1975-11-01', '1975-12-01'],
#               dtype='datetime64[ns]', name='Month', length=168, freq=None)
# DatetimeIndex(['1962-01-01', '1962-02-01', '1962-03-01', '1962-04-01',
#                '1962-05-01', '1962-06-01', '1962-07-01', '1962-08-01',
#                '1962-09-01', '1962-10-01',
#                ...
#                '1975-03-01', '1975-04-01', '1975-05-01', '1975-06-01',
#                '1975-07-01', '1975-08-01', '1975-09-01', '1975-10-01',
#                '1975-11-01', '1975-12-01'],
#               dtype='datetime64[ns]', name='Month', length=168, freq=None)

# %%
#讀取資料(圖表)
milk.plot()

# %%
#創建dataset
train_set = milk.head((1976-1962-1) * 12)
test_set = milk.tail(12)

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_set)
test_scaled = scaler.transform(test_set)

len(train_scaled)
# Out:
# 156

# %%
def build_train_data(data, past_monthes = 12, future_monthes = 1):
  X_train, Y_train = [], []

  for i in range(data.shape[0] + 1 - past_monthes - future_monthes):
    X_train.append(np.array(data[i : i + past_monthes]))
    Y_train.append(np.array(data[i + past_monthes : i + past_monthes + future_monthes]))
  
  return np.array(X_train).reshape([-1, 12]), np.array(Y_train).reshape([-1, 1])


x, y = build_train_data(train_scaled)
print('x shape:', x.shape, 'y shape:', y.shape)
# Out:
# x shape: (144, 12) y shape: (144, 1)

# %%
#構建網路模型
model = tf.keras.Sequential([          
      tf.keras.layers.Reshape((12, 1), batch_size = 1),
      tf.keras.layers.LSTM(40, return_sequences = True, activation='tanh', kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', input_shape = (12, 1)),
      tf.keras.layers.LSTM(40, return_sequences = True),
      tf.keras.layers.Dense(1, activation = 'linear'),
      tf.keras.layers.Reshape((12, 1), batch_size = 1),
      #tf.keras.layers.SimpleRNN(40, return_sequences = True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', input_shape = (12, 1)),
      tf.keras.layers.LSTM(40, return_sequences = True, activation='tanh', kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', input_shape = (12, 1)),
      tf.keras.layers.LSTM(40, return_sequences = True),
      tf.keras.layers.Dense(1, kernel_regularizer = regularizers.l1_l2(l1 = 1e-5, l2 = 1e-4), bias_regularizer = regularizers.l2(1e-4),
                            activity_regularizer = regularizers.l2(1e-5), activation = 'linear')
])

"""

# init layer
model = Sequential()

# emmbed word vectors
model.add(Embedding(len(d2v_model.wv.vocab)+1,20,input_length=X.shape[1],weights=[embedding_matrix],trainable=True))

# learn the correlations
def split_input(sequence):
     return sequence[:-1], tf.reshape(sequence[1:], (-1,1))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(3,activation="softmax"))

# output model skeleton
model.summary()
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=['acc'])

"""
# Out:
# '\n\n# init layer\nmodel = Sequential()\n\n# emmbed word vectors\nmodel.add(Embedding(len(d2v_model.wv.vocab)+1,20,input_length=X.shape[1],weights=[embedding_matrix],trainable=True))\n\n# learn the correlations\ndef split_input(sequence):\n     return sequence[:-1], tf.reshape(sequence[1:], (-1,1))\nmodel.add(LSTM(50,return_sequences=False))\nmodel.add(Dense(3,activation="softmax"))\n\n# output model skeleton\nmodel.summary()\nmodel.compile(optimizer="adam",loss="binary_crossentropy",metrics=[\'acc\'])\n\n'

# %%
#compile模型
model.compile(optimizer = optimizers.Adam(0.001), loss = losses.MeanSquaredError(), metrics = ["accuracy"])

# %%
#訓練模型
model.fit(x, y, epochs = 50, batch_size = 1, verbose = 1)
# Out:
# Epoch 1/50
# 144/144 [==============================] - 5s 7ms/step - loss: 0.0887 - accuracy: 0.0041
# Epoch 2/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0471 - accuracy: 0.0052
# Epoch 3/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0385 - accuracy: 0.0052
# Epoch 4/50
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0377 - accuracy: 0.0058
# Epoch 5/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0353 - accuracy: 0.0058
# Epoch 6/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0303 - accuracy: 0.0064
# Epoch 7/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0272 - accuracy: 0.0064
# Epoch 8/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0240 - accuracy: 0.0064
# Epoch 9/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0185 - accuracy: 0.0064
# Epoch 10/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0160 - accuracy: 0.0064
# Epoch 11/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0129 - accuracy: 0.0069
# Epoch 12/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0126 - accuracy: 0.0069
# Epoch 13/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0101 - accuracy: 0.0069
# Epoch 14/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0099 - accuracy: 0.0069
# Epoch 15/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0081 - accuracy: 0.0069
# Epoch 16/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0097 - accuracy: 0.0069
# Epoch 17/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0079 - accuracy: 0.0069
# Epoch 18/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0068 - accuracy: 0.0069
# Epoch 19/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0058 - accuracy: 0.0069
# Epoch 20/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0052 - accuracy: 0.0069
# Epoch 21/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0044 - accuracy: 0.0069
# Epoch 22/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0040 - accuracy: 0.0069
# Epoch 23/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0038 - accuracy: 0.0069
# Epoch 24/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0041 - accuracy: 0.0069
# Epoch 25/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0043 - accuracy: 0.0069
# Epoch 26/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0047 - accuracy: 0.0069
# Epoch 27/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0038 - accuracy: 0.0069
# Epoch 28/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0044 - accuracy: 0.0069
# Epoch 29/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0039 - accuracy: 0.0069
# Epoch 30/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0043 - accuracy: 0.0069
# Epoch 31/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0040 - accuracy: 0.0069
# Epoch 32/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0041 - accuracy: 0.0069
# Epoch 33/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0031 - accuracy: 0.0069
# Epoch 34/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0036 - accuracy: 0.0069
# Epoch 35/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0031 - accuracy: 0.0069
# Epoch 36/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0034 - accuracy: 0.0069
# Epoch 37/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0041 - accuracy: 0.0069
# Epoch 38/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0036 - accuracy: 0.0069
# Epoch 39/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 0.0069
# Epoch 40/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 0.0069
# Epoch 41/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0028 - accuracy: 0.0069
# Epoch 42/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 0.0069
# Epoch 43/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.0069
# Epoch 44/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0026 - accuracy: 0.0069
# Epoch 45/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0035 - accuracy: 0.0069
# Epoch 46/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 0.0069
# Epoch 47/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.0069
# Epoch 48/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 0.0069
# Epoch 49/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0028 - accuracy: 0.0069
# Epoch 50/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.0069

# %%
`train_seed = list(train_scaled[-12:].flatten())
print(np.array(train_seed[-12:]).reshape(1, 12).astype(np.float64))
print(train_seed)

# %%
train_seed = list(train_scaled[-12:].flatten())
print(np.array(train_seed[-12:]).reshape(1, 12).astype(np.float64))
print(train_seed)

# %%
x_train = np.array(train_seed[-12:]).reshape(1, 12).astype(np.float64)
print(model.predict(x_train)[0][0])

# %%
x_train = np.array(train_seed[-12:]).reshape(1, 12).astype(np.float64)
print(model.predict(x_train)[0][0])

# %%
#預測模型
from keras import models

train_seed = list(train_scaled[-12:].flatten())

def get_prediction(data_list):
    predict = []
    train_seed = data_list
    for i in range(12):
        x_train = np.array(train_seed[-12:]).reshape(1, 12).astype(np.float64)
        #x_train = np.array(train_seed[-12:]).reshape(1, 12)
        one_predict = model.predict(x_train)[0][0]
        predict.append(one_predict)
        train_seed.append(one_predict)

    return predict, train_seed

predict, train_seed = get_prediction(train_seed)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.

# %%
results = scaler.inverse_transform(np.array(predict).reshape(12, 1))
test_set['Generated'] = results
test_set
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Monthly milk production (pounds per cow)   Generated
# Month
# 1975-01-01                                       834  837.870361
# 1975-02-01                                       782  789.707581
# 1975-03-01                                       892  892.195801
# 1975-04-01                                       903  903.031494
# 1975-05-01                                       966  954.615112
# 1975-06-01                                       937  938.458008
# 1975-07-01                                       896  907.941589
# 1975-08-01                                       858  873.250427
# 1975-09-01                                       817  825.611023
# 1975-10-01                                       827  822.752380
# 1975-11-01                                       797  784.768494
# 1975-12-01                                       843  823.706421

# %%
test_set.plot()

# %%
true = milk.tail(12).to_numpy()
def mape(true, results):
    return np.mean(np.abs((results - true) / true)) * 100

print(mape(true, results))
# Out:
# 0.9425397401989971
